# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
import re
# %matplotlib inline

# %%
data = pd.read_csv(r'..\..\..\Week13\tableau-project\your-code\data\datasus.zip')

# %%
def trata_estado(estado):
    if estado in ['ES','MG','RJ','SP']:
        return 'SUDESTE'
    elif estado in ['PR','RS','SC']:
        return 'SUL'
    elif estado in ['AL','BA','CE','MA','PI','PE','PB','RN','SE']:
        return 'NORDESTE'
    elif estado in ['AC','AM','AP','PA','RO','RR','TO']:
        return 'NORTE'
    elif estado in ['GO','MT','MS','DF']:
        return 'CENTRO_OESTE'

# %%
def trata_mes(mes):
    if mes == '01':
        return 'Janeiro'
    elif mes == '02':
        return 'Fevereiro'
    elif mes == '03':
        return 'Março'
    elif mes == '04':
        return 'Abril'
    elif mes == '05':
        return 'Maio'
    elif mes == '06':
        return 'Junho'
    elif mes == '07':
        return 'Julho'
    elif mes == '08':
        return 'Agosto'
    elif mes == '09':
        return 'Setembro'
    elif mes == '10':
        return 'Outubro'
    elif mes == '11':
        return 'Novembro'
    elif mes == '12':
        return 'Dezembro'

# %%
data['MES'] = data.DTOBITO.apply(lambda x: (str(x)[-6:-4]))
data.MES = data.MES.astype(float)

# %%
data['REGIAO'] = data.UF.apply(lambda x: trata_estado(x))

# %%
#data['MES'] = data.DTOBITO.apply(lambda x: trata_mes(str(x)[-6:-4]))

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'CAUSABAS', 'DTOBITO', 'CAUSABAS_O', 'NOMMUN',
#        'NMRACACOR', 'NMESTCIV', 'NMSEXO', 'IDADE', 'POSICAO', 'NOME', 'IDHM',
#        'UF', 'CODCID', 'NMCID', 'MES', 'REGIAO'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0','NOME','CAUSABAS','CAUSABAS_O', 'POSICAO','DTOBITO', 'NMCID','UF','NOMMUN'],axis=1,inplace=True)

# %%
data.CODCID = data.CODCID.apply(lambda x: ''.join(re.findall('[\d]',x)))

# %%
data.CODCID = data.CODCID.astype(int)

# %%
data.dtypes
# Out:
# NMRACACOR     object
# NMESTCIV      object
# NMSEXO        object
# IDADE        float64
# IDHM         float64
# CODCID         int32
# MES          float64
# REGIAO        object
# dtype: object

# %%
data.dtypes
# Out:
# NMRACACOR     object
# NMESTCIV      object
# NMSEXO        object
# IDADE        float64
# IDHM         float64
# CODCID         int32
# MES          float64
# REGIAO        object
# dtype: object

# %%
data.loc[data.IDADE.isnull(), 'IDADE'] = -1

# %%
data.loc[data.NMSEXO.isnull(), 'NMSEXO'] = 'INDEFINIDO'

# %%
data.loc[data.NMRACACOR.isnull(), 'NMRACACOR'] = 'INDEFINIDO'

# %%
data.NMESTCIV = data.NMESTCIV.apply(lambda x : 'INDEFINIDO' if x != x else x)

# %%
data.isnull().sum()
# Out:
# NMRACACOR    0
# NMESTCIV     0
# NMSEXO       0
# IDADE        0
# IDHM         0
# CODCID       0
# MES          0
# REGIAO       0
# dtype: int64

# %%
data_ml = data.copy()

# %%
data_ml = pd.get_dummies(data, columns=['NMSEXO', 'NMRACACOR','NMESTCIV','REGIAO'])

# %%
data_ml.dtypes
# Out:
# IDADE                        float64
# IDHM                         float64
# CODCID                         int32
# MES                          float64
# NMSEXO_FEMININO                uint8
# NMSEXO_INDEFINIDO              uint8
# NMSEXO_MASCULINO               uint8
# NMRACACOR_BRANCA               uint8
# NMRACACOR_INDEFINIDO           uint8
# NMRACACOR_INDIGENA             uint8
# NMRACACOR_PARDA                uint8
# NMRACACOR_PRETA                uint8
# NMESTCIV_CASADO                uint8
# NMESTCIV_INDEFINIDO            uint8
# NMESTCIV_SEPARADO              uint8
# NMESTCIV_SOLTEIRO              uint8
# NMESTCIV_UNIAO CONSENSUAL      uint8
# NMESTCIV_VIUVO                 uint8
# REGIAO_CENTRO_OESTE            uint8
# REGIAO_NORDESTE                uint8
# REGIAO_NORTE                   uint8
# REGIAO_SUDESTE                 uint8
# REGIAO_SUL                     uint8
# dtype: object

# %%
data_ml.columns
# Out:
# Index(['IDADE', 'IDHM', 'CODCID', 'MES', 'NMSEXO_FEMININO',
#        'NMSEXO_INDEFINIDO', 'NMSEXO_MASCULINO', 'NMRACACOR_BRANCA',
#        'NMRACACOR_INDEFINIDO', 'NMRACACOR_INDIGENA', 'NMRACACOR_PARDA',
#        'NMRACACOR_PRETA', 'NMESTCIV_CASADO', 'NMESTCIV_INDEFINIDO',
#        'NMESTCIV_SEPARADO', 'NMESTCIV_SOLTEIRO', 'NMESTCIV_UNIAO CONSENSUAL',
#        'NMESTCIV_VIUVO', 'REGIAO_CENTRO_OESTE', 'REGIAO_NORDESTE',
#        'REGIAO_NORTE', 'REGIAO_SUDESTE', 'REGIAO_SUL'],
#       dtype='object')

# %%
sns.heatmap(data_ml.head(1000).corr())

# %%
data_bin = data_ml.head(10000)

# %% [markdown]
# * usar pca
# * 80 e 20

# %% [markdown]
# Árvore de decisão

# %%
data_bin = data_bin.dropna()

# %%
data_bin
# Out:
#       IDADE   IDHM  CODCID  MES  NMSEXO_FEMININO  NMSEXO_INDEFINIDO  \
# 0      20.0  0.532      58  9.0                0                  0
# 1      38.0  0.805      58  1.0                1                  0
# 2      29.0  0.805      58  5.0                0                  0
# 3      77.0  0.805      58  4.0                1                  0
# 4      60.0  0.805      58  2.0                0                  0
# ...     ...    ...     ...  ...              ...                ...
# 9995   57.0  0.717     149  5.0                1                  0
# 9996   85.0  0.717     149  5.0                0                  0
# 9997   80.0  0.717     149  1.0                1                  0
# 9998  111.0  0.717     149  1.0                1                  0
# 9999   82.0  0.717     149  5.0                1                  0
#
#       NMSEXO_MASCULINO  NMRACACOR_BRANCA  NMRACACOR_INDEFINIDO  \
# 0                    1                 0                     0
# 1                    0                 1                     0
# 2                    1                 1                     0
# 3                    0                 1                     0
# 4                    1                 1                     0
# ...                ...               ...                   ...
# 9995                 0                 0                     0
# 9996                 1                 0                     0
# 9997                 0                 0                     0
# 9998                 0                 1                     0
# 9999                 0                 1                     0
#
#       NMRACACOR_INDIGENA  ...  NMESTCIV_INDEFINIDO  NMESTCIV_SEPARADO  \
# 0                      1  ...                    1                  0
# 1                      0  ...                    0                  0
# 2                      0  ...                    0                  0
# 3                      0  ...                    0                  0
# 4                      0  ...                    0                  0
# ...                  ...  ...                  ...                ...
# 9995                   0  ...                    0                  0
# 9996                   0  ...                    0                  0
# 9997                   0  ...                    0                  0
# 9998                   0  ...                    0                  0
# 9999                   0  ...                    0                  0
#
#       NMESTCIV_SOLTEIRO  NMESTCIV_UNIAO CONSENSUAL  NMESTCIV_VIUVO  \
# 0                     0                          0               0
# 1                     1                          0               0
# 2                     0                          0               0
# 3                     0                          0               0
# 4                     0                          0               0
# ...                 ...                        ...             ...
# 9995                  0                          0               1
# 9996                  0                          0               1
# 9997                  0                          0               1
# 9998                  0                          0               1
# 9999                  0                          0               1
#
#       REGIAO_CENTRO_OESTE  REGIAO_NORDESTE  REGIAO_NORTE  REGIAO_SUDESTE  \
# 0                       0                0             1               0
# 1                       0                0             0               1
# 2                       0                0             0               1
# 3                       0                0             0               1
# 4                       0                0             0               1
# ...                   ...              ...           ...             ...
# 9995                    0                1             0               0
# 9996                    0                1             0               0
# 9997                    0                1             0               0
# 9998                    0                1             0               0
# 9999                    0                1             0               0
#
#       REGIAO_SUL
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 9995           0
# 9996           0
# 9997           0
# 9998           0
# 9999           0
#
# [10000 rows x 23 columns]

# %%
data_bin.CODCID.unique()
# Out:
# array([ 58,   9, 440, 149], dtype=int64)

# %%
[col for col in data_bin.columns if col not in ['IDADE_Q','IDADE']]
# Out:
# ['IDHM',
#  'CODCID',
#  'MES',
#  'NMSEXO_FEMININO',
#  'NMSEXO_INDEFINIDO',
#  'NMSEXO_MASCULINO',
#  'NMRACACOR_BRANCA',
#  'NMRACACOR_INDEFINIDO',
#  'NMRACACOR_INDIGENA',
#  'NMRACACOR_PARDA',
#  'NMRACACOR_PRETA',
#  'NMESTCIV_CASADO',
#  'NMESTCIV_INDEFINIDO',
#  'NMESTCIV_SEPARADO',
#  'NMESTCIV_SOLTEIRO',
#  'NMESTCIV_UNIAO CONSENSUAL',
#  'NMESTCIV_VIUVO',
#  'REGIAO_CENTRO_OESTE',
#  'REGIAO_NORDESTE',
#  'REGIAO_NORTE',
#  'REGIAO_SUDESTE',
#  'REGIAO_SUL']

# %%
data_bin['IDADE_Q'] = pd.qcut(data_bin['IDADE'],q=4,labels=['Infantil','Leite com Pêra','Meia-idade','Pé na Cova'])

# %%
data_bin.columns
# Out:
# Index(['IDADE', 'IDHM', 'CODCID', 'MES', 'NMSEXO_FEMININO',
#        'NMSEXO_INDEFINIDO', 'NMSEXO_MASCULINO', 'NMRACACOR_BRANCA',
#        'NMRACACOR_INDEFINIDO', 'NMRACACOR_INDIGENA', 'NMRACACOR_PARDA',
#        'NMRACACOR_PRETA', 'NMESTCIV_CASADO', 'NMESTCIV_INDEFINIDO',
#        'NMESTCIV_SEPARADO', 'NMESTCIV_SOLTEIRO', 'NMESTCIV_UNIAO CONSENSUAL',
#        'NMESTCIV_VIUVO', 'REGIAO_CENTRO_OESTE', 'REGIAO_NORDESTE',
#        'REGIAO_NORTE', 'REGIAO_SUDESTE', 'REGIAO_SUL', 'IDADE_Q'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(data_bin[['IDHM', 'CODCID', 'MES', 'NMSEXO_FEMININO', 'NMSEXO_MASCULINO',
                                                   'NMRACACOR_BRANCA','NMRACACOR_PARDA','NMESTCIV_CASADO', 'NMESTCIV_SEPARADO',
                                                   'NMESTCIV_SOLTEIRO', 'NMESTCIV_VIUVO','REGIAO_NORDESTE','REGIAO_SUDESTE']], 
                                                    data_bin['IDADE_Q'],
                                                    test_size=0.2)

# %%
tree = DecisionTreeClassifier(min_samples_leaf=10)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred = tree.predict(X_test)
y_pred
# Out:
# array(['Meia-idade', 'Leite com Pêra', 'Pé na Cova', ..., 'Meia-idade',
#        'Leite com Pêra', 'Leite com Pêra'], dtype=object)

# %%
sorted(list(zip(X_train.columns, tree.feature_importances_)), key=lambda x : x[1], reverse=True)
# Out:
# [('NMESTCIV_VIUVO', 0.24468118182213308),
#  ('IDHM', 0.22789749522688874),
#  ('MES', 0.18342776412826892),
#  ('CODCID', 0.09566283715795487),
#  ('NMESTCIV_CASADO', 0.07273450673214),
#  ('NMESTCIV_SOLTEIRO', 0.031058631881806138),
#  ('NMRACACOR_BRANCA', 0.030234606842889776),
#  ('REGIAO_SUDESTE', 0.024590633600552286),
#  ('NMSEXO_MASCULINO', 0.022732896212509523),
#  ('NMESTCIV_SEPARADO', 0.021249928670653426),
#  ('NMRACACOR_PARDA', 0.015968868062586985),
#  ('REGIAO_NORDESTE', 0.01547283967931657),
#  ('NMSEXO_FEMININO', 0.014287809982299596)]

# %%
from sklearn import tree as tr

# %%
print(tr.export_graphviz(tree, filled=True, rounded=True, special_characters=False, impurity=False, feature_names=X_train.columns) )
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname=helvetica] ;
# edge [fontname=helvetica] ;
# 0 [label="NMESTCIV_VIUVO <= 0.5\nsamples = 8000\nvalue = [2025, 2011, 2182, 1782]", fillcolor="#399de507"] ;
# 1 [label="NMESTCIV_CASADO <= 0.5\nsamples = 5626\nvalue = [1934, 1570, 1355, 767]", fillcolor="#e5813917"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="CODCID <= 103.5\nsamples = 3236\nvalue = [1412, 734, 649, 441]", fillcolor="#e5813945"] ;
# 1 -> 2 ;
# 3 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 1477\nvalue = [834, 204, 240, 199]", fillcolor="#e581397a"] ;
# 2 -> 3 ;
# 4 [label="NMESTCIV_SEPARADO <= 0.5\nsamples = 800\nvalue = [528, 79, 112, 81]", fillcolor="#e581399a"] ;
# 3 -> 4 ;
# 5 [label="REGIAO_NORDESTE <= 0.5\nsamples = 695\nvalue = [495, 51, 79, 70]", fillcolor="#e58139ac"] ;
# 4 -> 5 ;
# 6 [label="REGIAO_SUDESTE <= 0.5\nsamples = 375\nvalue = [293, 22, 31, 29]", fillcolor="#e58139c2"] ;
# 5 -> 6 ;
# 7 [label="IDHM <= 0.49\nsamples = 234\nvalue = [199, 8, 16, 11]", fillcolor="#e58139d6"] ;
# 6 -> 7 ;
# 8 [label="samples = 10\nvalue = [6, 1, 1, 2]", fillcolor="#e581397f"] ;
# 7 -> 8 ;
# 9 [label="IDHM <= 0.745\nsamples = 224\nvalue = [193, 7, 15, 9]", fillcolor="#e58139d9"] ;
# 7 -> 9 ;
# 10 [label="IDHM <= 0.546\nsamples = 150\nvalue = [135, 3, 8, 4]", fillcolor="#e58139e4"] ;
# 9 -> 10 ;
# 11 [label="samples = 23\nvalue = [23, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 10 -> 11 ;
# 12 [label="IDHM <= 0.591\nsamples = 127\nvalue = [112, 3, 8, 4]", fillcolor="#e58139df"] ;
# 10 -> 12 ;
# 13 [label="samples = 12\nvalue = [9, 0, 3, 0]", fillcolor="#e58139aa"] ;
# 12 -> 13 ;
# 14 [label="IDHM <= 0.731\nsamples = 115\nvalue = [103, 3, 5, 4]", fillcolor="#e58139e3"] ;
# 12 -> 14 ;
# 15 [label="IDHM <= 0.694\nsamples = 79\nvalue = [68, 3, 4, 4]", fillcolor="#e58139da"] ;
# 14 -> 15 ;
# 16 [label="NMRACACOR_PARDA <= 0.5\nsamples = 53\nvalue = [48, 2, 0, 3]", fillcolor="#e58139e6"] ;
# 15 -> 16 ;
# 17 [label="MES <= 3.5\nsamples = 32\nvalue = [31, 0, 0, 1]", fillcolor="#e58139f7"] ;
# 16 -> 17 ;
# 18 [label="samples = 13\nvalue = [12, 0, 0, 1]", fillcolor="#e58139ea"] ;
# 17 -> 18 ;
# 19 [label="samples = 19\nvalue = [19, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 17 -> 19 ;
# 20 [label="IDHM <= 0.655\nsamples = 21\nvalue = [17, 2, 0, 2]", fillcolor="#e58139c9"] ;
# 16 -> 20 ;
# 21 [label="samples = 10\nvalue = [7, 1, 0, 2]", fillcolor="#e581399f"] ;
# 20 -> 21 ;
# 22 [label="samples = 11\nvalue = [10, 1, 0, 0]", fillcolor="#e58139e6"] ;
# 20 -> 22 ;
# 23 [label="MES <= 6.0\nsamples = 26\nvalue = [20, 1, 4, 1]", fillcolor="#e58139b9"] ;
# 15 -> 23 ;
# 24 [label="samples = 12\nvalue = [10, 1, 0, 1]", fillcolor="#e58139d1"] ;
# 23 -> 24 ;
# 25 [label="samples = 14\nvalue = [10, 0, 4, 0]", fillcolor="#e5813999"] ;
# 23 -> 25 ;
# 26 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 36\nvalue = [35, 0, 1, 0]", fillcolor="#e58139f8"] ;
# 14 -> 26 ;
# 27 [label="samples = 15\nvalue = [14, 0, 1, 0]", fillcolor="#e58139ed"] ;
# 26 -> 27 ;
# 28 [label="samples = 21\nvalue = [21, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 26 -> 28 ;
# 29 [label="NMSEXO_FEMININO <= 0.5\nsamples = 74\nvalue = [58, 4, 7, 5]", fillcolor="#e58139c2"] ;
# 9 -> 29 ;
# 30 [label="MES <= 5.5\nsamples = 37\nvalue = [32, 3, 2, 0]", fillcolor="#e58139da"] ;
# 29 -> 30 ;
# 31 [label="samples = 15\nvalue = [11, 3, 1, 0]", fillcolor="#e58139aa"] ;
# 30 -> 31 ;
# 32 [label="NMRACACOR_PARDA <= 0.5\nsamples = 22\nvalue = [21, 0, 1, 0]", fillcolor="#e58139f3"] ;
# 30 -> 32 ;
# 33 [label="samples = 12\nvalue = [12, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 32 -> 33 ;
# 34 [label="samples = 10\nvalue = [9, 0, 1, 0]", fillcolor="#e58139e3"] ;
# 32 -> 34 ;
# 35 [label="IDHM <= 0.782\nsamples = 37\nvalue = [26, 1, 5, 5]", fillcolor="#e58139a7"] ;
# 29 -> 35 ;
# 36 [label="samples = 18\nvalue = [10, 1, 3, 4]", fillcolor="#e581396d"] ;
# 35 -> 36 ;
# 37 [label="samples = 19\nvalue = [16, 0, 2, 1]", fillcolor="#e58139d2"] ;
# 35 -> 37 ;
# 38 [label="IDHM <= 0.794\nsamples = 141\nvalue = [94, 14, 15, 18]", fillcolor="#e581399e"] ;
# 6 -> 38 ;
# 39 [label="IDHM <= 0.771\nsamples = 94\nvalue = [54, 12, 14, 14]", fillcolor="#e5813980"] ;
# 38 -> 39 ;
# 40 [label="IDHM <= 0.686\nsamples = 78\nvalue = [49, 9, 9, 11]", fillcolor="#e5813991"] ;
# 39 -> 40 ;
# 41 [label="samples = 17\nvalue = [7, 2, 3, 5]", fillcolor="#e581392a"] ;
# 40 -> 41 ;
# 42 [label="IDHM <= 0.734\nsamples = 61\nvalue = [42, 7, 6, 6]", fillcolor="#e58139a5"] ;
# 40 -> 42 ;
# 43 [label="NMRACACOR_PARDA <= 0.5\nsamples = 30\nvalue = [25, 1, 3, 1]", fillcolor="#e58139d0"] ;
# 42 -> 43 ;
# 44 [label="samples = 17\nvalue = [12, 1, 3, 1]", fillcolor="#e58139a4"] ;
# 43 -> 44 ;
# 45 [label="samples = 13\nvalue = [13, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 43 -> 45 ;
# 46 [label="MES <= 7.5\nsamples = 31\nvalue = [17, 6, 3, 5]", fillcolor="#e5813970"] ;
# 42 -> 46 ;
# 47 [label="samples = 16\nvalue = [6, 3, 2, 5]", fillcolor="#e5813917"] ;
# 46 -> 47 ;
# 48 [label="samples = 15\nvalue = [11, 3, 1, 0]", fillcolor="#e58139aa"] ;
# 46 -> 48 ;
# 49 [label="samples = 16\nvalue = [5, 3, 5, 3]", fillcolor="#e5813900"] ;
# 39 -> 49 ;
# 50 [label="MES <= 8.5\nsamples = 47\nvalue = [40, 2, 1, 4]", fillcolor="#e58139d5"] ;
# 38 -> 50 ;
# 51 [label="IDHM <= 0.801\nsamples = 30\nvalue = [27, 2, 1, 0]", fillcolor="#e58139e4"] ;
# 50 -> 51 ;
# 52 [label="samples = 11\nvalue = [9, 2, 0, 0]", fillcolor="#e58139c6"] ;
# 51 -> 52 ;
# 53 [label="samples = 19\nvalue = [18, 0, 1, 0]", fillcolor="#e58139f1"] ;
# 51 -> 53 ;
# 54 [label="samples = 17\nvalue = [13, 0, 0, 4]", fillcolor="#e58139b1"] ;
# 50 -> 54 ;
# 55 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 320\nvalue = [202, 29, 48, 41]", fillcolor="#e5813990"] ;
# 5 -> 55 ;
# 56 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 155\nvalue = [83, 18, 30, 24]", fillcolor="#e581396c"] ;
# 55 -> 56 ;
# 57 [label="IDHM <= 0.769\nsamples = 123\nvalue = [59, 17, 25, 22]", fillcolor="#e5813958"] ;
# 56 -> 57 ;
# 58 [label="MES <= 6.5\nsamples = 111\nvalue = [48, 17, 24, 22]", fillcolor="#e5813946"] ;
# 57 -> 58 ;
# 59 [label="IDHM <= 0.61\nsamples = 65\nvalue = [23, 14, 14, 14]", fillcolor="#e581392d"] ;
# 58 -> 59 ;
# 60 [label="samples = 18\nvalue = [11, 0, 2, 5]", fillcolor="#e5813976"] ;
# 59 -> 60 ;
# 61 [label="MES <= 5.5\nsamples = 47\nvalue = [12, 14, 12, 9]", fillcolor="#47e5390f"] ;
# 59 -> 61 ;
# 62 [label="IDHM <= 0.736\nsamples = 35\nvalue = [9, 11, 11, 4]", fillcolor="#47e53900"] ;
# 61 -> 62 ;
# 63 [label="IDHM <= 0.655\nsamples = 25\nvalue = [4, 9, 9, 3]", fillcolor="#47e53900"] ;
# 62 -> 63 ;
# 64 [label="samples = 14\nvalue = [2, 7, 4, 1]", fillcolor="#47e5394c"] ;
# 63 -> 64 ;
# 65 [label="samples = 11\nvalue = [2, 2, 5, 2]", fillcolor="#399de555"] ;
# 63 -> 65 ;
# 66 [label="samples = 10\nvalue = [5, 2, 2, 1]", fillcolor="#e5813960"] ;
# 62 -> 66 ;
# 67 [label="samples = 12\nvalue = [3, 3, 1, 5]", fillcolor="#d739e539"] ;
# 61 -> 67 ;
# 68 [label="IDHM <= 0.653\nsamples = 46\nvalue = [25, 3, 10, 8]", fillcolor="#e581396a"] ;
# 58 -> 68 ;
# 69 [label="samples = 16\nvalue = [6, 1, 5, 4]", fillcolor="#e5813917"] ;
# 68 -> 69 ;
# 70 [label="IDHM <= 0.737\nsamples = 30\nvalue = [19, 2, 5, 4]", fillcolor="#e581398f"] ;
# 68 -> 70 ;
# 71 [label="samples = 17\nvalue = [13, 1, 1, 2]", fillcolor="#e58139bb"] ;
# 70 -> 71 ;
# 72 [label="samples = 13\nvalue = [6, 1, 4, 2]", fillcolor="#e5813939"] ;
# 70 -> 72 ;
# 73 [label="samples = 12\nvalue = [11, 0, 1, 0]", fillcolor="#e58139e8"] ;
# 57 -> 73 ;
# 74 [label="MES <= 4.5\nsamples = 32\nvalue = [24, 1, 5, 2]", fillcolor="#e58139b3"] ;
# 56 -> 74 ;
# 75 [label="samples = 10\nvalue = [5, 1, 4, 0]", fillcolor="#e581392a"] ;
# 74 -> 75 ;
# 76 [label="IDHM <= 0.726\nsamples = 22\nvalue = [19, 0, 1, 2]", fillcolor="#e58139d9"] ;
# 74 -> 76 ;
# 77 [label="samples = 11\nvalue = [11, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 76 -> 77 ;
# 78 [label="samples = 11\nvalue = [8, 0, 1, 2]", fillcolor="#e58139aa"] ;
# 76 -> 78 ;
# 79 [label="IDHM <= 0.655\nsamples = 165\nvalue = [119, 11, 18, 17]", fillcolor="#e58139af"] ;
# 55 -> 79 ;
# 80 [label="MES <= 7.5\nsamples = 72\nvalue = [42, 6, 13, 11]", fillcolor="#e581397d"] ;
# 79 -> 80 ;
# 81 [label="IDHM <= 0.564\nsamples = 51\nvalue = [29, 2, 12, 8]", fillcolor="#e581396f"] ;
# 80 -> 81 ;
# 82 [label="samples = 11\nvalue = [4, 1, 3, 3]", fillcolor="#e5813920"] ;
# 81 -> 82 ;
# 83 [label="IDHM <= 0.589\nsamples = 40\nvalue = [25, 1, 9, 5]", fillcolor="#e5813984"] ;
# 81 -> 83 ;
# 84 [label="samples = 11\nvalue = [8, 0, 3, 0]", fillcolor="#e581399f"] ;
# 83 -> 84 ;
# 85 [label="IDHM <= 0.627\nsamples = 29\nvalue = [17, 1, 6, 5]", fillcolor="#e581397a"] ;
# 83 -> 85 ;
# 86 [label="samples = 16\nvalue = [8, 1, 3, 4]", fillcolor="#e5813955"] ;
# 85 -> 86 ;
# 87 [label="samples = 13\nvalue = [9, 0, 3, 1]", fillcolor="#e5813999"] ;
# 85 -> 87 ;
# 88 [label="IDHM <= 0.607\nsamples = 21\nvalue = [13, 4, 1, 3]", fillcolor="#e5813987"] ;
# 80 -> 88 ;
# 89 [label="samples = 11\nvalue = [10, 0, 1, 0]", fillcolor="#e58139e6"] ;
# 88 -> 89 ;
# 90 [label="samples = 10\nvalue = [3, 4, 0, 3]", fillcolor="#47e53924"] ;
# 88 -> 90 ;
# 91 [label="IDHM <= 0.678\nsamples = 93\nvalue = [77, 5, 5, 6]", fillcolor="#e58139d0"] ;
# 79 -> 91 ;
# 92 [label="samples = 17\nvalue = [17, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 91 -> 92 ;
# 93 [label="IDHM <= 0.726\nsamples = 76\nvalue = [60, 5, 5, 6]", fillcolor="#e58139c5"] ;
# 91 -> 93 ;
# 94 [label="IDHM <= 0.713\nsamples = 34\nvalue = [22, 4, 3, 5]", fillcolor="#e5813995"] ;
# 93 -> 94 ;
# 95 [label="samples = 18\nvalue = [13, 1, 2, 2]", fillcolor="#e58139af"] ;
# 94 -> 95 ;
# 96 [label="samples = 16\nvalue = [9, 3, 1, 3]", fillcolor="#e5813976"] ;
# 94 -> 96 ;
# 97 [label="MES <= 4.5\nsamples = 42\nvalue = [38, 1, 2, 1]", fillcolor="#e58139e6"] ;
# 93 -> 97 ;
# 98 [label="samples = 15\nvalue = [12, 1, 1, 1]", fillcolor="#e58139c8"] ;
# 97 -> 98 ;
# 99 [label="IDHM <= 0.761\nsamples = 27\nvalue = [26, 0, 1, 0]", fillcolor="#e58139f5"] ;
# 97 -> 99 ;
# 100 [label="samples = 13\nvalue = [13, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 99 -> 100 ;
# 101 [label="samples = 14\nvalue = [13, 0, 1, 0]", fillcolor="#e58139eb"] ;
# 99 -> 101 ;
# 102 [label="MES <= 7.5\nsamples = 105\nvalue = [33, 28, 33, 11]", fillcolor="#e5813900"] ;
# 4 -> 102 ;
# 103 [label="REGIAO_SUDESTE <= 0.5\nsamples = 70\nvalue = [20, 15, 25, 10]", fillcolor="#399de51a"] ;
# 102 -> 103 ;
# 104 [label="IDHM <= 0.767\nsamples = 39\nvalue = [10, 12, 10, 7]", fillcolor="#47e53912"] ;
# 103 -> 104 ;
# 105 [label="MES <= 4.5\nsamples = 26\nvalue = [4, 10, 7, 5]", fillcolor="#47e53928"] ;
# 104 -> 105 ;
# 106 [label="samples = 12\nvalue = [2, 7, 2, 1]", fillcolor="#47e53980"] ;
# 105 -> 106 ;
# 107 [label="samples = 14\nvalue = [2, 3, 5, 4]", fillcolor="#399de51a"] ;
# 105 -> 107 ;
# 108 [label="samples = 13\nvalue = [6, 2, 3, 2]", fillcolor="#e581394d"] ;
# 104 -> 108 ;
# 109 [label="NMSEXO_FEMININO <= 0.5\nsamples = 31\nvalue = [10, 3, 15, 3]", fillcolor="#399de53d"] ;
# 103 -> 109 ;
# 110 [label="samples = 16\nvalue = [7, 2, 7, 0]", fillcolor="#e5813900"] ;
# 109 -> 110 ;
# 111 [label="samples = 15\nvalue = [3, 1, 8, 3]", fillcolor="#399de56a"] ;
# 109 -> 111 ;
# 112 [label="IDHM <= 0.779\nsamples = 35\nvalue = [13, 13, 8, 1]", fillcolor="#e5813900"] ;
# 102 -> 112 ;
# 113 [label="MES <= 10.5\nsamples = 23\nvalue = [12, 6, 5, 0]", fillcolor="#e581395a"] ;
# 112 -> 113 ;
# 114 [label="samples = 13\nvalue = [7, 5, 1, 0]", fillcolor="#e5813940"] ;
# 113 -> 114 ;
# 115 [label="samples = 10\nvalue = [5, 1, 4, 0]", fillcolor="#e581392a"] ;
# 113 -> 115 ;
# 116 [label="samples = 12\nvalue = [1, 7, 3, 1]", fillcolor="#47e53971"] ;
# 112 -> 116 ;
# 117 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 677\nvalue = [306, 125, 128, 118]", fillcolor="#e5813953"] ;
# 3 -> 117 ;
# 118 [label="CODCID <= 33.5\nsamples = 372\nvalue = [137, 70, 82, 83]", fillcolor="#e5813930"] ;
# 117 -> 118 ;
# 119 [label="IDHM <= 0.597\nsamples = 360\nvalue = [128, 69, 81, 82]", fillcolor="#e581392a"] ;
# 118 -> 119 ;
# 120 [label="MES <= 8.5\nsamples = 32\nvalue = [9, 1, 10, 12]", fillcolor="#d739e517"] ;
# 119 -> 120 ;
# 121 [label="IDHM <= 0.574\nsamples = 20\nvalue = [7, 0, 8, 5]", fillcolor="#399de514"] ;
# 120 -> 121 ;
# 122 [label="samples = 10\nvalue = [2, 0, 4, 4]", fillcolor="#399de500"] ;
# 121 -> 122 ;
# 123 [label="samples = 10\nvalue = [5, 0, 4, 1]", fillcolor="#e581392a"] ;
# 121 -> 123 ;
# 124 [label="samples = 12\nvalue = [2, 1, 2, 7]", fillcolor="#d739e580"] ;
# 120 -> 124 ;
# 125 [label="IDHM <= 0.757\nsamples = 328\nvalue = [119, 68, 71, 70]", fillcolor="#e5813930"] ;
# 119 -> 125 ;
# 126 [label="MES <= 1.5\nsamples = 185\nvalue = [58, 45, 43, 39]", fillcolor="#e5813918"] ;
# 125 -> 126 ;
# 127 [label="IDHM <= 0.677\nsamples = 21\nvalue = [10, 1, 5, 5]", fillcolor="#e5813950"] ;
# 126 -> 127 ;
# 128 [label="samples = 10\nvalue = [7, 0, 1, 2]", fillcolor="#e581399f"] ;
# 127 -> 128 ;
# 129 [label="samples = 11\nvalue = [3, 1, 4, 3]", fillcolor="#399de520"] ;
# 127 -> 129 ;
# 130 [label="MES <= 11.5\nsamples = 164\nvalue = [48, 44, 38, 34]", fillcolor="#e5813908"] ;
# 126 -> 130 ;
# 131 [label="IDHM <= 0.609\nsamples = 153\nvalue = [45, 43, 33, 32]", fillcolor="#e5813905"] ;
# 130 -> 131 ;
# 132 [label="samples = 10\nvalue = [4, 4, 2, 0]", fillcolor="#e5813900"] ;
# 131 -> 132 ;
# 133 [label="IDHM <= 0.696\nsamples = 143\nvalue = [41, 39, 31, 32]", fillcolor="#e5813905"] ;
# 131 -> 133 ;
# 134 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 49\nvalue = [10, 13, 10, 16]", fillcolor="#d739e515"] ;
# 133 -> 134 ;
# 135 [label="MES <= 6.5\nsamples = 35\nvalue = [10, 10, 4, 11]", fillcolor="#d739e50a"] ;
# 134 -> 135 ;
# 136 [label="samples = 16\nvalue = [7, 4, 1, 4]", fillcolor="#e5813940"] ;
# 135 -> 136 ;
# 137 [label="samples = 19\nvalue = [3, 6, 3, 7]", fillcolor="#d739e514"] ;
# 135 -> 137 ;
# 138 [label="samples = 14\nvalue = [0, 3, 6, 5]", fillcolor="#399de51c"] ;
# 134 -> 138 ;
# 139 [label="IDHM <= 0.753\nsamples = 94\nvalue = [31, 26, 21, 16]", fillcolor="#e5813913"] ;
# 133 -> 139 ;
# 140 [label="MES <= 6.5\nsamples = 78\nvalue = [26, 21, 20, 11]", fillcolor="#e5813916"] ;
# 139 -> 140 ;
# 141 [label="MES <= 3.5\nsamples = 39\nvalue = [9, 10, 12, 8]", fillcolor="#399de512"] ;
# 140 -> 141 ;
# 142 [label="samples = 15\nvalue = [6, 2, 4, 3]", fillcolor="#e581392e"] ;
# 141 -> 142 ;
# 143 [label="REGIAO_NORDESTE <= 0.5\nsamples = 24\nvalue = [3, 8, 8, 5]", fillcolor="#47e53900"] ;
# 141 -> 143 ;
# 144 [label="samples = 14\nvalue = [1, 6, 3, 4]", fillcolor="#47e53933"] ;
# 143 -> 144 ;
# 145 [label="samples = 10\nvalue = [2, 2, 5, 1]", fillcolor="#399de560"] ;
# 143 -> 145 ;
# 146 [label="IDHM <= 0.736\nsamples = 39\nvalue = [17, 11, 8, 3]", fillcolor="#e5813937"] ;
# 140 -> 146 ;
# 147 [label="REGIAO_NORDESTE <= 0.5\nsamples = 24\nvalue = [10, 9, 3, 2]", fillcolor="#e5813911"] ;
# 146 -> 147 ;
# 148 [label="samples = 14\nvalue = [7, 4, 1, 2]", fillcolor="#e581394c"] ;
# 147 -> 148 ;
# 149 [label="samples = 10\nvalue = [3, 5, 2, 0]", fillcolor="#47e53949"] ;
# 147 -> 149 ;
# 150 [label="samples = 15\nvalue = [7, 2, 5, 1]", fillcolor="#e5813933"] ;
# 146 -> 150 ;
# 151 [label="samples = 16\nvalue = [5, 5, 1, 5]", fillcolor="#e5813900"] ;
# 139 -> 151 ;
# 152 [label="samples = 11\nvalue = [3, 1, 5, 2]", fillcolor="#399de540"] ;
# 130 -> 152 ;
# 153 [label="IDHM <= 0.793\nsamples = 143\nvalue = [61, 23, 28, 31]", fillcolor="#e5813944"] ;
# 125 -> 153 ;
# 154 [label="IDHM <= 0.777\nsamples = 83\nvalue = [41, 11, 18, 13]", fillcolor="#e581395a"] ;
# 153 -> 154 ;
# 155 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 63\nvalue = [27, 8, 16, 12]", fillcolor="#e581393c"] ;
# 154 -> 155 ;
# 156 [label="IDHM <= 0.771\nsamples = 41\nvalue = [19, 7, 6, 9]", fillcolor="#e5813950"] ;
# 155 -> 156 ;
# 157 [label="IDHM <= 0.764\nsamples = 25\nvalue = [10, 4, 4, 7]", fillcolor="#e581392a"] ;
# 156 -> 157 ;
# 158 [label="samples = 12\nvalue = [6, 3, 0, 3]", fillcolor="#e5813955"] ;
# 157 -> 158 ;
# 159 [label="samples = 13\nvalue = [4, 1, 4, 4]", fillcolor="#e5813900"] ;
# 157 -> 159 ;
# 160 [label="samples = 16\nvalue = [9, 3, 2, 2]", fillcolor="#e5813976"] ;
# 156 -> 160 ;
# 161 [label="IDHM <= 0.772\nsamples = 22\nvalue = [8, 1, 10, 3]", fillcolor="#399de524"] ;
# 155 -> 161 ;
# 162 [label="samples = 10\nvalue = [6, 0, 3, 1]", fillcolor="#e581396d"] ;
# 161 -> 162 ;
# 163 [label="samples = 12\nvalue = [2, 1, 7, 2]", fillcolor="#399de580"] ;
# 161 -> 163 ;
# 164 [label="samples = 20\nvalue = [14, 3, 2, 1]", fillcolor="#e58139a5"] ;
# 154 -> 164 ;
# 165 [label="REGIAO_SUDESTE <= 0.5\nsamples = 60\nvalue = [20, 12, 10, 18]", fillcolor="#e581390c"] ;
# 153 -> 165 ;
# 166 [label="samples = 20\nvalue = [7, 3, 7, 3]", fillcolor="#e5813900"] ;
# 165 -> 166 ;
# 167 [label="MES <= 5.5\nsamples = 40\nvalue = [13, 9, 3, 15]", fillcolor="#d739e513"] ;
# 165 -> 167 ;
# 168 [label="samples = 18\nvalue = [4, 4, 0, 10]", fillcolor="#d739e56d"] ;
# 167 -> 168 ;
# 169 [label="MES <= 8.5\nsamples = 22\nvalue = [9, 5, 3, 5]", fillcolor="#e581393c"] ;
# 167 -> 169 ;
# 170 [label="samples = 10\nvalue = [5, 2, 1, 2]", fillcolor="#e5813960"] ;
# 169 -> 170 ;
# 171 [label="samples = 12\nvalue = [4, 3, 2, 3]", fillcolor="#e581391c"] ;
# 169 -> 171 ;
# 172 [label="samples = 12\nvalue = [9, 1, 1, 1]", fillcolor="#e58139b9"] ;
# 118 -> 172 ;
# 173 [label="CODCID <= 33.5\nsamples = 305\nvalue = [169, 55, 46, 35]", fillcolor="#e5813974"] ;
# 117 -> 173 ;
# 174 [label="IDHM <= 0.667\nsamples = 283\nvalue = [149, 53, 46, 35]", fillcolor="#e581396a"] ;
# 173 -> 174 ;
# 175 [label="MES <= 5.5\nsamples = 73\nvalue = [32, 10, 17, 14]", fillcolor="#e5813944"] ;
# 174 -> 175 ;
# 176 [label="IDHM <= 0.587\nsamples = 34\nvalue = [14, 7, 11, 2]", fillcolor="#e5813921"] ;
# 175 -> 176 ;
# 177 [label="samples = 12\nvalue = [3, 4, 5, 0]", fillcolor="#399de520"] ;
# 176 -> 177 ;
# 178 [label="IDHM <= 0.625\nsamples = 22\nvalue = [11, 3, 6, 2]", fillcolor="#e5813950"] ;
# 176 -> 178 ;
# 179 [label="samples = 11\nvalue = [7, 1, 2, 1]", fillcolor="#e581398e"] ;
# 178 -> 179 ;
# 180 [label="samples = 11\nvalue = [4, 2, 4, 1]", fillcolor="#e5813900"] ;
# 178 -> 180 ;
# 181 [label="MES <= 8.5\nsamples = 39\nvalue = [18, 3, 6, 12]", fillcolor="#e5813939"] ;
# 175 -> 181 ;
# 182 [label="IDHM <= 0.612\nsamples = 23\nvalue = [13, 1, 1, 8]", fillcolor="#e5813955"] ;
# 181 -> 182 ;
# 183 [label="samples = 13\nvalue = [9, 0, 0, 4]", fillcolor="#e581398e"] ;
# 182 -> 183 ;
# 184 [label="samples = 10\nvalue = [4, 1, 1, 4]", fillcolor="#e5813900"] ;
# 182 -> 184 ;
# 185 [label="samples = 16\nvalue = [5, 2, 5, 4]", fillcolor="#e5813900"] ;
# 181 -> 185 ;
# 186 [label="REGIAO_NORDESTE <= 0.5\nsamples = 210\nvalue = [117, 43, 29, 21]", fillcolor="#e5813971"] ;
# 174 -> 186 ;
# 187 [label="MES <= 3.5\nsamples = 131\nvalue = [64, 30, 21, 16]", fillcolor="#e5813956"] ;
# 186 -> 187 ;
# 188 [label="IDHM <= 0.774\nsamples = 35\nvalue = [12, 12, 3, 8]", fillcolor="#e5813900"] ;
# 187 -> 188 ;
# 189 [label="samples = 15\nvalue = [3, 7, 0, 5]", fillcolor="#47e53933"] ;
# 188 -> 189 ;
# 190 [label="MES <= 1.5\nsamples = 20\nvalue = [9, 5, 3, 3]", fillcolor="#e5813944"] ;
# 188 -> 190 ;
# 191 [label="samples = 10\nvalue = [3, 3, 3, 1]", fillcolor="#e5813900"] ;
# 190 -> 191 ;
# 192 [label="samples = 10\nvalue = [6, 2, 0, 2]", fillcolor="#e581397f"] ;
# 190 -> 192 ;
# 193 [label="MES <= 10.5\nsamples = 96\nvalue = [52, 18, 18, 8]", fillcolor="#e581396f"] ;
# 187 -> 193 ;
# 194 [label="NMRACACOR_PARDA <= 0.5\nsamples = 72\nvalue = [44, 10, 12, 6]", fillcolor="#e5813988"] ;
# 193 -> 194 ;
# 195 [label="IDHM <= 0.758\nsamples = 42\nvalue = [30, 2, 8, 2]", fillcolor="#e58139a5"] ;
# 194 -> 195 ;
# 196 [label="samples = 16\nvalue = [14, 1, 1, 0]", fillcolor="#e58139dd"] ;
# 195 -> 196 ;
# 197 [label="MES <= 6.5\nsamples = 26\nvalue = [16, 1, 7, 2]", fillcolor="#e5813979"] ;
# 195 -> 197 ;
# 198 [label="samples = 13\nvalue = [7, 1, 3, 2]", fillcolor="#e5813966"] ;
# 197 -> 198 ;
# 199 [label="samples = 13\nvalue = [9, 0, 4, 0]", fillcolor="#e581398e"] ;
# 197 -> 199 ;
# 200 [label="IDHM <= 0.734\nsamples = 30\nvalue = [14, 8, 4, 4]", fillcolor="#e5813946"] ;
# 194 -> 200 ;
# 201 [label="samples = 10\nvalue = [4, 1, 2, 3]", fillcolor="#e5813924"] ;
# 200 -> 201 ;
# 202 [label="IDHM <= 0.764\nsamples = 20\nvalue = [10, 7, 2, 1]", fillcolor="#e581393b"] ;
# 200 -> 202 ;
# 203 [label="samples = 10\nvalue = [4, 5, 1, 0]", fillcolor="#47e5392a"] ;
# 202 -> 203 ;
# 204 [label="samples = 10\nvalue = [6, 2, 1, 1]", fillcolor="#e581397f"] ;
# 202 -> 204 ;
# 205 [label="MES <= 11.5\nsamples = 24\nvalue = [8, 8, 6, 2]", fillcolor="#e5813900"] ;
# 193 -> 205 ;
# 206 [label="samples = 12\nvalue = [3, 3, 4, 2]", fillcolor="#399de51c"] ;
# 205 -> 206 ;
# 207 [label="samples = 12\nvalue = [5, 5, 2, 0]", fillcolor="#e5813900"] ;
# 205 -> 207 ;
# 208 [label="IDHM <= 0.761\nsamples = 79\nvalue = [53, 13, 8, 5]", fillcolor="#e581399b"] ;
# 186 -> 208 ;
# 209 [label="IDHM <= 0.743\nsamples = 57\nvalue = [36, 10, 7, 4]", fillcolor="#e581398d"] ;
# 208 -> 209 ;
# 210 [label="MES <= 7.5\nsamples = 36\nvalue = [25, 4, 3, 4]", fillcolor="#e58139a7"] ;
# 209 -> 210 ;
# 211 [label="IDHM <= 0.705\nsamples = 23\nvalue = [14, 2, 3, 4]", fillcolor="#e5813986"] ;
# 210 -> 211 ;
# 212 [label="samples = 12\nvalue = [7, 2, 1, 2]", fillcolor="#e5813980"] ;
# 211 -> 212 ;
# 213 [label="samples = 11\nvalue = [7, 0, 2, 2]", fillcolor="#e581398e"] ;
# 211 -> 213 ;
# 214 [label="samples = 13\nvalue = [11, 2, 0, 0]", fillcolor="#e58139d1"] ;
# 210 -> 214 ;
# 215 [label="MES <= 5.5\nsamples = 21\nvalue = [11, 6, 4, 0]", fillcolor="#e5813955"] ;
# 209 -> 215 ;
# 216 [label="samples = 10\nvalue = [4, 3, 3, 0]", fillcolor="#e5813924"] ;
# 215 -> 216 ;
# 217 [label="samples = 11\nvalue = [7, 3, 1, 0]", fillcolor="#e5813980"] ;
# 215 -> 217 ;
# 218 [label="MES <= 4.5\nsamples = 22\nvalue = [17, 3, 1, 1]", fillcolor="#e58139bc"] ;
# 208 -> 218 ;
# 219 [label="samples = 10\nvalue = [8, 2, 0, 0]", fillcolor="#e58139bf"] ;
# 218 -> 219 ;
# 220 [label="samples = 12\nvalue = [9, 1, 1, 1]", fillcolor="#e58139b9"] ;
# 218 -> 220 ;
# 221 [label="IDHM <= 0.675\nsamples = 22\nvalue = [20, 2, 0, 0]", fillcolor="#e58139e6"] ;
# 173 -> 221 ;
# 222 [label="samples = 10\nvalue = [8, 2, 0, 0]", fillcolor="#e58139bf"] ;
# 221 -> 222 ;
# 223 [label="samples = 12\nvalue = [12, 0, 0, 0]", fillcolor="#e58139ff"] ;
# 221 -> 223 ;
# 224 [label="NMSEXO_FEMININO <= 0.5\nsamples = 1759\nvalue = [578, 530, 409, 242]", fillcolor="#e581390a"] ;
# 2 -> 224 ;
# 225 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 796\nvalue = [312, 244, 154, 86]", fillcolor="#e581391f"] ;
# 224 -> 225 ;
# 226 [label="NMESTCIV_SEPARADO <= 0.5\nsamples = 380\nvalue = [101, 136, 90, 53]", fillcolor="#47e53920"] ;
# 225 -> 226 ;
# 227 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 244\nvalue = [52, 88, 57, 47]", fillcolor="#47e5392a"] ;
# 226 -> 227 ;
# 228 [label="REGIAO_SUDESTE <= 0.5\nsamples = 187\nvalue = [36, 75, 36, 40]", fillcolor="#47e5393d"] ;
# 227 -> 228 ;
# 229 [label="MES <= 1.5\nsamples = 177\nvalue = [33, 74, 35, 35]", fillcolor="#47e53946"] ;
# 228 -> 229 ;
# 230 [label="samples = 18\nvalue = [4, 4, 4, 6]", fillcolor="#d739e524"] ;
# 229 -> 230 ;
# 231 [label="IDHM <= 0.755\nsamples = 159\nvalue = [29, 70, 31, 29]", fillcolor="#47e5394e"] ;
# 229 -> 231 ;
# 232 [label="REGIAO_NORDESTE <= 0.5\nsamples = 122\nvalue = [22, 50, 24, 26]", fillcolor="#47e53940"] ;
# 231 -> 232 ;
# 233 [label="samples = 12\nvalue = [4, 2, 3, 3]", fillcolor="#e581391c"] ;
# 232 -> 233 ;
# 234 [label="NMRACACOR_PARDA <= 0.5\nsamples = 110\nvalue = [18, 48, 21, 23]", fillcolor="#47e53949"] ;
# 232 -> 234 ;
# 235 [label="MES <= 5.5\nsamples = 35\nvalue = [9, 13, 7, 6]", fillcolor="#47e53927"] ;
# 234 -> 235 ;
# 236 [label="samples = 11\nvalue = [3, 2, 3, 3]", fillcolor="#e5813900"] ;
# 235 -> 236 ;
# 237 [label="IDHM <= 0.698\nsamples = 24\nvalue = [6, 11, 4, 3]", fillcolor="#47e53947"] ;
# 235 -> 237 ;
# 238 [label="samples = 10\nvalue = [4, 5, 1, 0]", fillcolor="#47e5392a"] ;
# 237 -> 238 ;
# 239 [label="samples = 14\nvalue = [2, 6, 3, 3]", fillcolor="#47e53946"] ;
# 237 -> 239 ;
# 240 [label="MES <= 5.5\nsamples = 75\nvalue = [9, 35, 14, 17]", fillcolor="#47e5394f"] ;
# 234 -> 240 ;
# 241 [label="IDHM <= 0.662\nsamples = 28\nvalue = [4, 14, 2, 8]", fillcolor="#47e5394c"] ;
# 240 -> 241 ;
# 242 [label="samples = 10\nvalue = [3, 4, 1, 2]", fillcolor="#47e53924"] ;
# 241 -> 242 ;
# 243 [label="samples = 18\nvalue = [1, 10, 1, 6]", fillcolor="#47e53955"] ;
# 241 -> 243 ;
# 244 [label="IDHM <= 0.655\nsamples = 47\nvalue = [5, 21, 12, 9]", fillcolor="#47e53942"] ;
# 240 -> 244 ;
# 245 [label="samples = 17\nvalue = [0, 9, 6, 2]", fillcolor="#47e53946"] ;
# 244 -> 245 ;
# 246 [label="IDHM <= 0.721\nsamples = 30\nvalue = [5, 12, 6, 7]", fillcolor="#47e53937"] ;
# 244 -> 246 ;
# 247 [label="samples = 20\nvalue = [5, 6, 3, 6]", fillcolor="#47e53900"] ;
# 246 -> 247 ;
# 248 [label="samples = 10\nvalue = [0, 6, 3, 1]", fillcolor="#47e5396d"] ;
# 246 -> 248 ;
# 249 [label="IDHM <= 0.761\nsamples = 37\nvalue = [7, 20, 7, 3]", fillcolor="#47e5396f"] ;
# 231 -> 249 ;
# 250 [label="samples = 18\nvalue = [2, 13, 3, 0]", fillcolor="#47e539aa"] ;
# 249 -> 250 ;
# 251 [label="samples = 19\nvalue = [5, 7, 4, 3]", fillcolor="#47e53924"] ;
# 249 -> 251 ;
# 252 [label="samples = 10\nvalue = [3, 1, 1, 5]", fillcolor="#d739e549"] ;
# 228 -> 252 ;
# 253 [label="REGIAO_NORDESTE <= 0.5\nsamples = 57\nvalue = [16, 13, 21, 7]", fillcolor="#399de51f"] ;
# 227 -> 253 ;
# 254 [label="MES <= 5.5\nsamples = 29\nvalue = [11, 11, 6, 1]", fillcolor="#e5813900"] ;
# 253 -> 254 ;
# 255 [label="samples = 12\nvalue = [3, 7, 2, 0]", fillcolor="#47e53971"] ;
# 254 -> 255 ;
# 256 [label="samples = 17\nvalue = [8, 4, 4, 1]", fillcolor="#e581394e"] ;
# 254 -> 256 ;
# 257 [label="MES <= 7.5\nsamples = 28\nvalue = [5, 2, 15, 6]", fillcolor="#399de568"] ;
# 253 -> 257 ;
# 258 [label="samples = 16\nvalue = [4, 1, 7, 4]", fillcolor="#399de540"] ;
# 257 -> 258 ;
# 259 [label="samples = 12\nvalue = [1, 1, 8, 2]", fillcolor="#399de599"] ;
# 257 -> 259 ;
# 260 [label="NMRACACOR_PARDA <= 0.5\nsamples = 136\nvalue = [49, 48, 33, 6]", fillcolor="#e5813903"] ;
# 226 -> 260 ;
# 261 [label="MES <= 8.5\nsamples = 82\nvalue = [22, 31, 24, 5]", fillcolor="#47e5391f"] ;
# 260 -> 261 ;
# 262 [label="MES <= 5.5\nsamples = 53\nvalue = [10, 19, 20, 4]", fillcolor="#399de508"] ;
# 261 -> 262 ;
# 263 [label="REGIAO_SUDESTE <= 0.5\nsamples = 34\nvalue = [7, 14, 9, 4]", fillcolor="#47e53933"] ;
# 262 -> 263 ;
# 264 [label="samples = 19\nvalue = [1, 9, 6, 3]", fillcolor="#47e5393b"] ;
# 263 -> 264 ;
# 265 [label="samples = 15\nvalue = [6, 5, 3, 1]", fillcolor="#e581391a"] ;
# 263 -> 265 ;
# 266 [label="samples = 19\nvalue = [3, 5, 11, 0]", fillcolor="#399de56d"] ;
# 262 -> 266 ;
# 267 [label="REGIAO_SUDESTE <= 0.5\nsamples = 29\nvalue = [12, 12, 4, 1]", fillcolor="#e5813900"] ;
# 261 -> 267 ;
# 268 [label="samples = 19\nvalue = [6, 10, 3, 0]", fillcolor="#47e5394e"] ;
# 267 -> 268 ;
# 269 [label="samples = 10\nvalue = [6, 2, 1, 1]", fillcolor="#e581397f"] ;
# 267 -> 269 ;
# 270 [label="REGIAO_SUDESTE <= 0.5\nsamples = 54\nvalue = [27, 17, 9, 1]", fillcolor="#e5813945"] ;
# 260 -> 270 ;
# 271 [label="IDHM <= 0.708\nsamples = 36\nvalue = [21, 8, 6, 1]", fillcolor="#e5813976"] ;
# 270 -> 271 ;
# 272 [label="samples = 10\nvalue = [5, 4, 1, 0]", fillcolor="#e581392a"] ;
# 271 -> 272 ;
# 273 [label="IDHM <= 0.768\nsamples = 26\nvalue = [16, 4, 5, 1]", fillcolor="#e5813986"] ;
# 271 -> 273 ;
# 274 [label="samples = 15\nvalue = [8, 2, 4, 1]", fillcolor="#e581395d"] ;
# 273 -> 274 ;
# 275 [label="samples = 11\nvalue = [8, 2, 1, 0]", fillcolor="#e58139aa"] ;
# 273 -> 275 ;
# 276 [label="samples = 18\nvalue = [6, 9, 3, 0]", fillcolor="#47e53940"] ;
# 270 -> 276 ;
# 277 [label="IDHM <= 0.766\nsamples = 416\nvalue = [211, 108, 64, 33]", fillcolor="#e5813955"] ;
# 225 -> 277 ;
# 278 [label="MES <= 7.5\nsamples = 220\nvalue = [99, 66, 34, 21]", fillcolor="#e5813937"] ;
# 277 -> 278 ;
# 279 [label="MES <= 2.5\nsamples = 138\nvalue = [54, 43, 24, 17]", fillcolor="#e581391e"] ;
# 278 -> 279 ;
# 280 [label="IDHM <= 0.757\nsamples = 30\nvalue = [13, 13, 1, 3]", fillcolor="#e5813900"] ;
# 279 -> 280 ;
# 281 [label="MES <= 1.5\nsamples = 20\nvalue = [10, 8, 0, 2]", fillcolor="#e581392a"] ;
# 280 -> 281 ;
# 282 [label="samples = 10\nvalue = [5, 4, 0, 1]", fillcolor="#e581392a"] ;
# 281 -> 282 ;
# 283 [label="samples = 10\nvalue = [5, 4, 0, 1]", fillcolor="#e581392a"] ;
# 281 -> 283 ;
# 284 [label="samples = 10\nvalue = [3, 5, 1, 1]", fillcolor="#47e53949"] ;
# 280 -> 284 ;
# 285 [label="MES <= 3.5\nsamples = 108\nvalue = [41, 30, 23, 14]", fillcolor="#e5813924"] ;
# 279 -> 285 ;
# 286 [label="IDHM <= 0.724\nsamples = 25\nvalue = [7, 6, 9, 3]", fillcolor="#399de51c"] ;
# 285 -> 286 ;
# 287 [label="samples = 15\nvalue = [6, 3, 5, 1]", fillcolor="#e581391a"] ;
# 286 -> 287 ;
# 288 [label="samples = 10\nvalue = [1, 3, 4, 2]", fillcolor="#399de524"] ;
# 286 -> 288 ;
# 289 [label="MES <= 5.5\nsamples = 83\nvalue = [34, 24, 14, 11]", fillcolor="#e581392b"] ;
# 285 -> 289 ;
# 290 [label="IDHM <= 0.712\nsamples = 36\nvalue = [14, 14, 4, 4]", fillcolor="#e5813900"] ;
# 289 -> 290 ;
# 291 [label="samples = 13\nvalue = [5, 6, 0, 2]", fillcolor="#47e53920"] ;
# 290 -> 291 ;
# 292 [label="NMRACACOR_PARDA <= 0.5\nsamples = 23\nvalue = [9, 8, 4, 2]", fillcolor="#e5813911"] ;
# 290 -> 292 ;
# 293 [label="samples = 10\nvalue = [5, 3, 2, 0]", fillcolor="#e5813949"] ;
# 292 -> 293 ;
# 294 [label="samples = 13\nvalue = [4, 5, 2, 2]", fillcolor="#47e5391c"] ;
# 292 -> 294 ;
# 295 [label="IDHM <= 0.668\nsamples = 47\nvalue = [20, 10, 10, 7]", fillcolor="#e5813945"] ;
# 289 -> 295 ;
# 296 [label="samples = 17\nvalue = [5, 4, 4, 4]", fillcolor="#e5813914"] ;
# 295 -> 296 ;
# 297 [label="IDHM <= 0.719\nsamples = 30\nvalue = [15, 6, 6, 3]", fillcolor="#e5813960"] ;
# 295 -> 297 ;
# 298 [label="samples = 13\nvalue = [6, 4, 2, 1]", fillcolor="#e5813939"] ;
# 297 -> 298 ;
# 299 [label="samples = 17\nvalue = [9, 2, 4, 2]", fillcolor="#e5813962"] ;
# 297 -> 299 ;
# 300 [label="REGIAO_SUDESTE <= 0.5\nsamples = 82\nvalue = [45, 23, 10, 4]", fillcolor="#e581395f"] ;
# 278 -> 300 ;
# 301 [label="NMRACACOR_PARDA <= 0.5\nsamples = 59\nvalue = [31, 14, 10, 4]", fillcolor="#e5813960"] ;
# 300 -> 301 ;
# 302 [label="IDHM <= 0.696\nsamples = 23\nvalue = [9, 8, 4, 2]", fillcolor="#e5813911"] ;
# 301 -> 302 ;
# 303 [label="samples = 11\nvalue = [3, 4, 2, 2]", fillcolor="#47e53920"] ;
# 302 -> 303 ;
# 304 [label="samples = 12\nvalue = [6, 4, 2, 0]", fillcolor="#e5813940"] ;
# 302 -> 304 ;
# 305 [label="IDHM <= 0.669\nsamples = 36\nvalue = [22, 6, 6, 2]", fillcolor="#e5813988"] ;
# 301 -> 305 ;
# 306 [label="samples = 12\nvalue = [10, 1, 0, 1]", fillcolor="#e58139d1"] ;
# 305 -> 306 ;
# 307 [label="IDHM <= 0.721\nsamples = 24\nvalue = [12, 5, 6, 1]", fillcolor="#e5813955"] ;
# 305 -> 307 ;
# 308 [label="samples = 10\nvalue = [5, 0, 4, 1]", fillcolor="#e581392a"] ;
# 307 -> 308 ;
# 309 [label="samples = 14\nvalue = [7, 5, 2, 0]", fillcolor="#e5813939"] ;
# 307 -> 309 ;
# 310 [label="NMRACACOR_PARDA <= 0.5\nsamples = 23\nvalue = [14, 9, 0, 0]", fillcolor="#e581395b"] ;
# 300 -> 310 ;
# 311 [label="samples = 10\nvalue = [7, 3, 0, 0]", fillcolor="#e5813992"] ;
# 310 -> 311 ;
# 312 [label="samples = 13\nvalue = [7, 6, 0, 0]", fillcolor="#e5813924"] ;
# 310 -> 312 ;
# 313 [label="MES <= 11.5\nsamples = 196\nvalue = [112, 42, 30, 12]", fillcolor="#e5813974"] ;
# 277 -> 313 ;
# 314 [label="IDHM <= 0.776\nsamples = 181\nvalue = [101, 41, 28, 11]", fillcolor="#e581396d"] ;
# 313 -> 314 ;
# 315 [label="MES <= 6.5\nsamples = 58\nvalue = [29, 12, 13, 4]", fillcolor="#e581395b"] ;
# 314 -> 315 ;
# 316 [label="MES <= 3.5\nsamples = 30\nvalue = [18, 6, 4, 2]", fillcolor="#e581397f"] ;
# 315 -> 316 ;
# 317 [label="samples = 15\nvalue = [6, 5, 3, 1]", fillcolor="#e581391a"] ;
# 316 -> 317 ;
# 318 [label="samples = 15\nvalue = [12, 1, 1, 1]", fillcolor="#e58139c8"] ;
# 316 -> 318 ;
# 319 [label="MES <= 9.5\nsamples = 28\nvalue = [11, 6, 9, 2]", fillcolor="#e581391b"] ;
# 315 -> 319 ;
# 320 [label="samples = 16\nvalue = [4, 4, 6, 2]", fillcolor="#399de52a"] ;
# 319 -> 320 ;
# 321 [label="samples = 12\nvalue = [7, 2, 3, 0]", fillcolor="#e5813971"] ;
# 319 -> 321 ;
# 322 [label="MES <= 2.5\nsamples = 123\nvalue = [72, 29, 15, 7]", fillcolor="#e5813975"] ;
# 314 -> 322 ;
# 323 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 29\nvalue = [18, 3, 6, 2]", fillcolor="#e5813985"] ;
# 322 -> 323 ;
# 324 [label="samples = 11\nvalue = [6, 1, 4, 0]", fillcolor="#e5813949"] ;
# 323 -> 324 ;
# 325 [label="samples = 18\nvalue = [12, 2, 2, 2]", fillcolor="#e581399f"] ;
# 323 -> 325 ;
# 326 [label="REGIAO_SUDESTE <= 0.5\nsamples = 94\nvalue = [54, 26, 9, 5]", fillcolor="#e5813969"] ;
# 322 -> 326 ;
# 327 [label="MES <= 7.5\nsamples = 37\nvalue = [25, 9, 3, 0]", fillcolor="#e5813992"] ;
# 326 -> 327 ;
# 328 [label="NMRACACOR_PARDA <= 0.5\nsamples = 21\nvalue = [13, 7, 1, 0]", fillcolor="#e581396d"] ;
# 327 -> 328 ;
# 329 [label="samples = 10\nvalue = [5, 4, 1, 0]", fillcolor="#e581392a"] ;
# 328 -> 329 ;
# 330 [label="samples = 11\nvalue = [8, 3, 0, 0]", fillcolor="#e581399f"] ;
# 328 -> 330 ;
# 331 [label="samples = 16\nvalue = [12, 2, 2, 0]", fillcolor="#e58139b6"] ;
# 327 -> 331 ;
# 332 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 57\nvalue = [29, 17, 6, 5]", fillcolor="#e581394d"] ;
# 326 -> 332 ;
# 333 [label="MES <= 8.5\nsamples = 21\nvalue = [9, 7, 2, 3]", fillcolor="#e5813924"] ;
# 332 -> 333 ;
# 334 [label="samples = 10\nvalue = [6, 2, 0, 2]", fillcolor="#e581397f"] ;
# 333 -> 334 ;
# 335 [label="samples = 11\nvalue = [3, 5, 2, 1]", fillcolor="#47e53940"] ;
# 333 -> 335 ;
# 336 [label="MES <= 4.5\nsamples = 36\nvalue = [20, 10, 4, 2]", fillcolor="#e5813962"] ;
# 332 -> 336 ;
# 337 [label="samples = 10\nvalue = [4, 4, 2, 0]", fillcolor="#e5813900"] ;
# 336 -> 337 ;
# 338 [label="MES <= 8.5\nsamples = 26\nvalue = [16, 6, 2, 2]", fillcolor="#e5813980"] ;
# 336 -> 338 ;
# 339 [label="samples = 11\nvalue = [6, 3, 1, 1]", fillcolor="#e5813960"] ;
# 338 -> 339 ;
# 340 [label="samples = 15\nvalue = [10, 3, 1, 1]", fillcolor="#e5813995"] ;
# 338 -> 340 ;
# 341 [label="samples = 15\nvalue = [11, 1, 2, 1]", fillcolor="#e58139b1"] ;
# 313 -> 341 ;
# 342 [label="CODCID <= 294.5\nsamples = 963\nvalue = [266, 286, 255, 156]", fillcolor="#47e53907"] ;
# 224 -> 342 ;
# 343 [label="IDHM <= 0.719\nsamples = 938\nvalue = [260, 285, 244, 149]", fillcolor="#47e53909"] ;
# 342 -> 343 ;
# 344 [label="IDHM <= 0.688\nsamples = 231\nvalue = [75, 82, 49, 25]", fillcolor="#47e5390b"] ;
# 343 -> 344 ;
# 345 [label="MES <= 9.5\nsamples = 154\nvalue = [47, 45, 41, 21]", fillcolor="#e5813905"] ;
# 344 -> 345 ;
# 346 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 127\nvalue = [34, 39, 34, 20]", fillcolor="#47e5390e"] ;
# 345 -> 346 ;
# 347 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 63\nvalue = [21, 21, 14, 7]", fillcolor="#e5813900"] ;
# 346 -> 347 ;
# 348 [label="IDHM <= 0.61\nsamples = 53\nvalue = [14, 19, 13, 7]", fillcolor="#47e53921"] ;
# 347 -> 348 ;
# 349 [label="samples = 12\nvalue = [1, 4, 4, 3]", fillcolor="#47e53900"] ;
# 348 -> 349 ;
# 350 [label="MES <= 6.5\nsamples = 41\nvalue = [13, 15, 9, 4]", fillcolor="#47e53912"] ;
# 348 -> 350 ;
# 351 [label="MES <= 4.5\nsamples = 26\nvalue = [8, 10, 7, 1]", fillcolor="#47e5391c"] ;
# 350 -> 351 ;
# 352 [label="samples = 13\nvalue = [3, 5, 4, 1]", fillcolor="#47e5391c"] ;
# 351 -> 352 ;
# 353 [label="samples = 13\nvalue = [5, 5, 3, 0]", fillcolor="#e5813900"] ;
# 351 -> 353 ;
# 354 [label="samples = 15\nvalue = [5, 5, 2, 3]", fillcolor="#e5813900"] ;
# 350 -> 354 ;
# 355 [label="samples = 10\nvalue = [7, 2, 1, 0]", fillcolor="#e581399f"] ;
# 347 -> 355 ;
# 356 [label="MES <= 2.5\nsamples = 64\nvalue = [13, 18, 20, 13]", fillcolor="#399de50b"] ;
# 346 -> 356 ;
# 357 [label="samples = 12\nvalue = [2, 2, 6, 2]", fillcolor="#399de566"] ;
# 356 -> 357 ;
# 358 [label="IDHM <= 0.676\nsamples = 52\nvalue = [11, 16, 14, 11]", fillcolor="#47e5390d"] ;
# 356 -> 358 ;
# 359 [label="IDHM <= 0.646\nsamples = 36\nvalue = [9, 10, 11, 6]", fillcolor="#399de50a"] ;
# 358 -> 359 ;
# 360 [label="MES <= 6.5\nsamples = 23\nvalue = [6, 7, 5, 5]", fillcolor="#47e5390f"] ;
# 359 -> 360 ;
# 361 [label="samples = 13\nvalue = [3, 4, 4, 2]", fillcolor="#47e53900"] ;
# 360 -> 361 ;
# 362 [label="samples = 10\nvalue = [3, 3, 1, 3]", fillcolor="#e5813900"] ;
# 360 -> 362 ;
# 363 [label="samples = 13\nvalue = [3, 3, 6, 1]", fillcolor="#399de54d"] ;
# 359 -> 363 ;
# 364 [label="samples = 16\nvalue = [2, 6, 3, 5]", fillcolor="#47e53917"] ;
# 358 -> 364 ;
# 365 [label="MES <= 11.5\nsamples = 27\nvalue = [13, 6, 7, 1]", fillcolor="#e581394c"] ;
# 345 -> 365 ;
# 366 [label="samples = 13\nvalue = [8, 3, 2, 0]", fillcolor="#e5813980"] ;
# 365 -> 366 ;
# 367 [label="samples = 14\nvalue = [5, 3, 5, 1]", fillcolor="#e5813900"] ;
# 365 -> 367 ;
# 368 [label="MES <= 8.5\nsamples = 77\nvalue = [28, 37, 8, 4]", fillcolor="#47e5392f"] ;
# 344 -> 368 ;
# 369 [label="MES <= 6.5\nsamples = 50\nvalue = [20, 21, 7, 2]", fillcolor="#47e53908"] ;
# 368 -> 369 ;
# 370 [label="IDHM <= 0.712\nsamples = 39\nvalue = [11, 20, 6, 2]", fillcolor="#47e53952"] ;
# 369 -> 370 ;
# 371 [label="samples = 19\nvalue = [8, 6, 4, 1]", fillcolor="#e5813927"] ;
# 370 -> 371 ;
# 372 [label="samples = 20\nvalue = [3, 14, 2, 1]", fillcolor="#47e539a5"] ;
# 370 -> 372 ;
# 373 [label="samples = 11\nvalue = [9, 1, 1, 0]", fillcolor="#e58139cc"] ;
# 369 -> 373 ;
# 374 [label="NMRACACOR_PARDA <= 0.5\nsamples = 27\nvalue = [8, 16, 1, 2]", fillcolor="#47e5396b"] ;
# 368 -> 374 ;
# 375 [label="samples = 14\nvalue = [5, 7, 1, 1]", fillcolor="#47e53939"] ;
# 374 -> 375 ;
# 376 [label="samples = 13\nvalue = [3, 9, 0, 1]", fillcolor="#47e53999"] ;
# 374 -> 376 ;
# 377 [label="IDHM <= 0.721\nsamples = 707\nvalue = [185, 203, 195, 124]", fillcolor="#47e53904"] ;
# 343 -> 377 ;
# 378 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 77\nvalue = [12, 22, 20, 23]", fillcolor="#d739e505"] ;
# 377 -> 378 ;
# 379 [label="MES <= 3.5\nsamples = 54\nvalue = [9, 19, 14, 12]", fillcolor="#47e53920"] ;
# 378 -> 379 ;
# 380 [label="samples = 13\nvalue = [0, 8, 1, 4]", fillcolor="#47e53971"] ;
# 379 -> 380 ;
# 381 [label="MES <= 6.5\nsamples = 41\nvalue = [9, 11, 13, 8]", fillcolor="#399de511"] ;
# 379 -> 381 ;
# 382 [label="samples = 11\nvalue = [4, 2, 3, 2]", fillcolor="#e5813920"] ;
# 381 -> 382 ;
# 383 [label="MES <= 9.5\nsamples = 30\nvalue = [5, 9, 10, 6]", fillcolor="#399de50c"] ;
# 381 -> 383 ;
# 384 [label="samples = 15\nvalue = [1, 5, 5, 4]", fillcolor="#47e53900"] ;
# 383 -> 384 ;
# 385 [label="samples = 15\nvalue = [4, 4, 5, 2]", fillcolor="#399de517"] ;
# 383 -> 385 ;
# 386 [label="MES <= 7.5\nsamples = 23\nvalue = [3, 3, 6, 11]", fillcolor="#d739e54b"] ;
# 378 -> 386 ;
# 387 [label="samples = 12\nvalue = [1, 2, 5, 4]", fillcolor="#399de520"] ;
# 386 -> 387 ;
# 388 [label="samples = 11\nvalue = [2, 1, 1, 7]", fillcolor="#d739e58e"] ;
# 386 -> 388 ;
# 389 [label="MES <= 8.5\nsamples = 630\nvalue = [173, 181, 175, 101]", fillcolor="#47e53903"] ;
# 377 -> 389 ;
# 390 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 419\nvalue = [105, 114, 126, 74]", fillcolor="#399de50a"] ;
# 389 -> 390 ;
# 391 [label="REGIAO_SUDESTE <= 0.5\nsamples = 267\nvalue = [75, 75, 74, 43]", fillcolor="#e5813900"] ;
# 390 -> 391 ;
# 392 [label="NMESTCIV_SEPARADO <= 0.5\nsamples = 232\nvalue = [65, 58, 69, 40]", fillcolor="#399de506"] ;
# 391 -> 392 ;
# 393 [label="MES <= 1.5\nsamples = 217\nvalue = [58, 52, 67, 40]", fillcolor="#399de50e"] ;
# 392 -> 393 ;
# 394 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 36\nvalue = [11, 14, 10, 1]", fillcolor="#47e5391f"] ;
# 393 -> 394 ;
# 395 [label="samples = 15\nvalue = [4, 5, 6, 0]", fillcolor="#399de51a"] ;
# 394 -> 395 ;
# 396 [label="IDHM <= 0.768\nsamples = 21\nvalue = [7, 9, 4, 1]", fillcolor="#47e53924"] ;
# 394 -> 396 ;
# 397 [label="samples = 11\nvalue = [3, 4, 3, 1]", fillcolor="#47e53920"] ;
# 396 -> 397 ;
# 398 [label="samples = 10\nvalue = [4, 5, 1, 0]", fillcolor="#47e5392a"] ;
# 396 -> 398 ;
# 399 [label="MES <= 2.5\nsamples = 181\nvalue = [47, 38, 57, 39]", fillcolor="#399de513"] ;
# 393 -> 399 ;
# 400 [label="NMRACACOR_PARDA <= 0.5\nsamples = 32\nvalue = [13, 5, 6, 8]", fillcolor="#e5813935"] ;
# 399 -> 400 ;
# 401 [label="samples = 11\nvalue = [4, 3, 0, 4]", fillcolor="#e5813900"] ;
# 400 -> 401 ;
# 402 [label="samples = 21\nvalue = [9, 2, 6, 4]", fillcolor="#e5813933"] ;
# 400 -> 402 ;
# 403 [label="IDHM <= 0.815\nsamples = 149\nvalue = [34, 33, 51, 31]", fillcolor="#399de526"] ;
# 399 -> 403 ;
# 404 [label="MES <= 6.5\nsamples = 136\nvalue = [33, 28, 45, 30]", fillcolor="#399de51e"] ;
# 403 -> 404 ;
# 405 [label="IDHM <= 0.766\nsamples = 83\nvalue = [20, 13, 27, 23]", fillcolor="#399de511"] ;
# 404 -> 405 ;
# 406 [label="MES <= 5.5\nsamples = 52\nvalue = [9, 8, 20, 15]", fillcolor="#399de522"] ;
# 405 -> 406 ;
# 407 [label="NMRACACOR_PARDA <= 0.5\nsamples = 40\nvalue = [8, 6, 13, 13]", fillcolor="#399de500"] ;
# 406 -> 407 ;
# 408 [label="samples = 14\nvalue = [4, 0, 5, 5]", fillcolor="#399de500"] ;
# 407 -> 408 ;
# 409 [label="MES <= 3.5\nsamples = 26\nvalue = [4, 6, 8, 8]", fillcolor="#399de500"] ;
# 407 -> 409 ;
# 410 [label="samples = 10\nvalue = [2, 3, 4, 1]", fillcolor="#399de524"] ;
# 409 -> 410 ;
# 411 [label="samples = 16\nvalue = [2, 3, 4, 7]", fillcolor="#d739e540"] ;
# 409 -> 411 ;
# 412 [label="samples = 12\nvalue = [1, 2, 7, 2]", fillcolor="#399de580"] ;
# 406 -> 412 ;
# 413 [label="MES <= 4.5\nsamples = 31\nvalue = [11, 5, 7, 8]", fillcolor="#e5813921"] ;
# 405 -> 413 ;
# 414 [label="samples = 14\nvalue = [4, 3, 3, 4]", fillcolor="#e5813900"] ;
# 413 -> 414 ;
# 415 [label="samples = 17\nvalue = [7, 2, 4, 4]", fillcolor="#e581393b"] ;
# 413 -> 415 ;
# 416 [label="NMRACACOR_PARDA <= 0.5\nsamples = 53\nvalue = [13, 15, 18, 7]", fillcolor="#399de514"] ;
# 404 -> 416 ;
# 417 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 22\nvalue = [6, 7, 5, 4]", fillcolor="#47e53910"] ;
# 416 -> 417 ;
# 418 [label="samples = 12\nvalue = [4, 4, 3, 1]", fillcolor="#e5813900"] ;
# 417 -> 418 ;
# 419 [label="samples = 10\nvalue = [2, 3, 2, 3]", fillcolor="#47e53900"] ;
# 417 -> 419 ;
# 420 [label="IDHM <= 0.764\nsamples = 31\nvalue = [7, 8, 13, 3]", fillcolor="#399de537"] ;
# 416 -> 420 ;
# 421 [label="samples = 18\nvalue = [3, 6, 6, 3]", fillcolor="#47e53900"] ;
# 420 -> 421 ;
# 422 [label="samples = 13\nvalue = [4, 2, 7, 0]", fillcolor="#399de555"] ;
# 420 -> 422 ;
# 423 [label="samples = 13\nvalue = [1, 5, 6, 1]", fillcolor="#399de520"] ;
# 403 -> 423 ;
# 424 [label="samples = 15\nvalue = [7, 6, 2, 0]", fillcolor="#e581391c"] ;
# 392 -> 424 ;
# 425 [label="MES <= 5.5\nsamples = 35\nvalue = [10, 17, 5, 3]", fillcolor="#47e53947"] ;
# 391 -> 425 ;
# 426 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 22\nvalue = [8, 8, 3, 3]", fillcolor="#e5813900"] ;
# 425 -> 426 ;
# 427 [label="samples = 10\nvalue = [4, 5, 1, 0]", fillcolor="#47e5392a"] ;
# 426 -> 427 ;
# 428 [label="samples = 12\nvalue = [4, 3, 2, 3]", fillcolor="#e581391c"] ;
# 426 -> 428 ;
# 429 [label="samples = 13\nvalue = [2, 9, 2, 0]", fillcolor="#47e539a2"] ;
# 425 -> 429 ;
# 430 [label="MES <= 4.5\nsamples = 152\nvalue = [30, 39, 52, 31]", fillcolor="#399de51d"] ;
# 390 -> 430 ;
# 431 [label="NMESTCIV_SEPARADO <= 0.5\nsamples = 80\nvalue = [21, 16, 28, 15]", fillcolor="#399de51e"] ;
# 430 -> 431 ;
# 432 [label="MES <= 2.5\nsamples = 65\nvalue = [18, 14, 19, 14]", fillcolor="#399de505"] ;
# 431 -> 432 ;
# 433 [label="IDHM <= 0.771\nsamples = 29\nvalue = [6, 10, 7, 6]", fillcolor="#47e53923"] ;
# 432 -> 433 ;
# 434 [label="samples = 13\nvalue = [3, 3, 2, 5]", fillcolor="#d739e533"] ;
# 433 -> 434 ;
# 435 [label="samples = 16\nvalue = [3, 7, 5, 1]", fillcolor="#47e5392e"] ;
# 433 -> 435 ;
# 436 [label="MES <= 3.5\nsamples = 36\nvalue = [12, 4, 12, 8]", fillcolor="#e5813900"] ;
# 432 -> 436 ;
# 437 [label="samples = 18\nvalue = [7, 1, 4, 6]", fillcolor="#e5813915"] ;
# 436 -> 437 ;
# 438 [label="samples = 18\nvalue = [5, 3, 8, 2]", fillcolor="#399de53b"] ;
# 436 -> 438 ;
# 439 [label="samples = 15\nvalue = [3, 2, 9, 1]", fillcolor="#399de57f"] ;
# 431 -> 439 ;
# 440 [label="REGIAO_SUDESTE <= 0.5\nsamples = 72\nvalue = [9, 23, 24, 16]", fillcolor="#399de505"] ;
# 430 -> 440 ;
# 441 [label="IDHM <= 0.771\nsamples = 47\nvalue = [6, 17, 11, 13]", fillcolor="#47e5391e"] ;
# 440 -> 441 ;
# 442 [label="samples = 12\nvalue = [1, 6, 3, 2]", fillcolor="#47e53955"] ;
# 441 -> 442 ;
# 443 [label="MES <= 6.5\nsamples = 35\nvalue = [5, 11, 8, 11]", fillcolor="#47e53900"] ;
# 441 -> 443 ;
# 444 [label="samples = 15\nvalue = [3, 3, 4, 5]", fillcolor="#d739e517"] ;
# 443 -> 444 ;
# 445 [label="NMESTCIV_SOLTEIRO <= 0.5\nsamples = 20\nvalue = [2, 8, 4, 6]", fillcolor="#47e53924"] ;
# 443 -> 445 ;
# 446 [label="samples = 10\nvalue = [0, 4, 3, 3]", fillcolor="#47e53924"] ;
# 445 -> 446 ;
# 447 [label="samples = 10\nvalue = [2, 4, 1, 3]", fillcolor="#47e53924"] ;
# 445 -> 447 ;
# 448 [label="samples = 25\nvalue = [3, 6, 13, 3]", fillcolor="#399de55e"] ;
# 440 -> 448 ;
# 449 [label="IDHM <= 0.814\nsamples = 211\nvalue = [68, 67, 49, 27]", fillcolor="#e5813902"] ;
# 389 -> 449 ;
# 450 [label="IDHM <= 0.757\nsamples = 198\nvalue = [63, 66, 43, 26]", fillcolor="#47e53906"] ;
# 449 -> 450 ;
# 451 [label="IDHM <= 0.723\nsamples = 30\nvalue = [12, 6, 9, 3]", fillcolor="#e5813924"] ;
# 450 -> 451 ;
# 452 [label="samples = 19\nvalue = [8, 6, 3, 2]", fillcolor="#e5813927"] ;
# 451 -> 452 ;
# 453 [label="samples = 11\nvalue = [4, 0, 6, 1]", fillcolor="#399de549"] ;
# 451 -> 453 ;
# 454 [label="MES <= 11.5\nsamples = 168\nvalue = [51, 60, 34, 23]", fillcolor="#47e53914"] ;
# 450 -> 454 ;
# 455 [label="IDHM <= 0.766\nsamples = 131\nvalue = [43, 49, 21, 18]", fillcolor="#47e53911"] ;
# 454 -> 455 ;
# 456 [label="MES <= 10.5\nsamples = 29\nvalue = [8, 14, 4, 3]", fillcolor="#47e53949"] ;
# 455 -> 456 ;
# 457 [label="samples = 19\nvalue = [4, 10, 4, 1]", fillcolor="#47e53966"] ;
# 456 -> 457 ;
# 458 [label="samples = 10\nvalue = [4, 4, 0, 2]", fillcolor="#e5813900"] ;
# 456 -> 458 ;
# 459 [label="IDHM <= 0.771\nsamples = 102\nvalue = [35, 35, 17, 15]", fillcolor="#e5813900"] ;
# 455 -> 459 ;
# 460 [label="samples = 12\nvalue = [4, 2, 4, 2]", fillcolor="#e5813900"] ;
# 459 -> 460 ;
# 461 [label="MES <= 10.5\nsamples = 90\nvalue = [31, 33, 13, 13]", fillcolor="#47e53909"] ;
# 459 -> 461 ;
# 462 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 56\nvalue = [17, 22, 9, 8]", fillcolor="#47e53921"] ;
# 461 -> 462 ;
# 463 [label="MES <= 9.5\nsamples = 23\nvalue = [5, 12, 3, 3]", fillcolor="#47e53963"] ;
# 462 -> 463 ;
# 464 [label="samples = 10\nvalue = [3, 5, 1, 1]", fillcolor="#47e53949"] ;
# 463 -> 464 ;
# 465 [label="samples = 13\nvalue = [2, 7, 2, 2]", fillcolor="#47e53974"] ;
# 463 -> 465 ;
# 466 [label="MES <= 9.5\nsamples = 33\nvalue = [12, 10, 6, 5]", fillcolor="#e5813916"] ;
# 462 -> 466 ;
# 467 [label="samples = 17\nvalue = [5, 5, 4, 3]", fillcolor="#e5813900"] ;
# 466 -> 467 ;
# 468 [label="samples = 16\nvalue = [7, 5, 2, 2]", fillcolor="#e581392e"] ;
# 466 -> 468 ;
# 469 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 34\nvalue = [14, 11, 4, 5]", fillcolor="#e5813921"] ;
# 461 -> 469 ;
# 470 [label="samples = 18\nvalue = [10, 4, 2, 2]", fillcolor="#e581396d"] ;
# 469 -> 470 ;
# 471 [label="samples = 16\nvalue = [4, 7, 2, 3]", fillcolor="#47e53940"] ;
# 469 -> 471 ;
# 472 [label="REGIAO_NORDESTE <= 0.5\nsamples = 37\nvalue = [8, 11, 13, 5]", fillcolor="#399de514"] ;
# 454 -> 472 ;
# 473 [label="samples = 22\nvalue = [8, 4, 8, 2]", fillcolor="#e5813900"] ;
# 472 -> 473 ;
# 474 [label="samples = 15\nvalue = [0, 7, 5, 3]", fillcolor="#47e53933"] ;
# 472 -> 474 ;
# 475 [label="samples = 13\nvalue = [5, 1, 6, 1]", fillcolor="#399de520"] ;
# 449 -> 475 ;
# 476 [label="IDHM <= 0.674\nsamples = 25\nvalue = [6, 1, 11, 7]", fillcolor="#399de539"] ;
# 342 -> 476 ;
# 477 [label="samples = 13\nvalue = [1, 0, 8, 4]", fillcolor="#399de571"] ;
# 476 -> 477 ;
# 478 [label="samples = 12\nvalue = [5, 1, 3, 3]", fillcolor="#e5813939"] ;
# 476 -> 478 ;
# 479 [label="CODCID <= 33.5\nsamples = 2390\nvalue = [522, 836, 706, 326]", fillcolor="#47e53914"] ;
# 1 -> 479 ;
# 480 [label="IDHM <= 0.613\nsamples = 753\nvalue = [134, 214, 251, 154]", fillcolor="#399de512"] ;
# 479 -> 480 ;
# 481 [label="MES <= 5.5\nsamples = 75\nvalue = [10, 12, 24, 29]", fillcolor="#d739e519"] ;
# 480 -> 481 ;
# 482 [label="IDHM <= 0.576\nsamples = 38\nvalue = [7, 11, 10, 10]", fillcolor="#47e53909"] ;
# 481 -> 482 ;
# 483 [label="samples = 12\nvalue = [4, 3, 0, 5]", fillcolor="#d739e520"] ;
# 482 -> 483 ;
# 484 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 26\nvalue = [3, 8, 10, 5]", fillcolor="#399de51c"] ;
# 482 -> 484 ;
# 485 [label="samples = 13\nvalue = [1, 3, 7, 2]", fillcolor="#399de566"] ;
# 484 -> 485 ;
# 486 [label="samples = 13\nvalue = [2, 5, 3, 3]", fillcolor="#47e53933"] ;
# 484 -> 486 ;
# 487 [label="IDHM <= 0.576\nsamples = 37\nvalue = [3, 1, 14, 19]", fillcolor="#d739e537"] ;
# 481 -> 487 ;
# 488 [label="samples = 13\nvalue = [0, 0, 8, 5]", fillcolor="#399de560"] ;
# 487 -> 488 ;
# 489 [label="IDHM <= 0.592\nsamples = 24\nvalue = [3, 1, 6, 14]", fillcolor="#d739e571"] ;
# 487 -> 489 ;
# 490 [label="samples = 10\nvalue = [2, 1, 3, 4]", fillcolor="#d739e524"] ;
# 489 -> 490 ;
# 491 [label="samples = 14\nvalue = [1, 0, 3, 10]", fillcolor="#d739e5a2"] ;
# 489 -> 491 ;
# 492 [label="NMSEXO_FEMININO <= 0.5\nsamples = 678\nvalue = [124, 202, 227, 125]", fillcolor="#399de50d"] ;
# 480 -> 492 ;
# 493 [label="NMRACACOR_BRANCA <= 0.5\nsamples = 387\nvalue = [54, 115, 133, 85]", fillcolor="#399de511"] ;
# 492 -> 493 ;
# 494 [label="MES <= 3.5\nsamples = 195\nvalue = [34, 64, 62, 35]", fillcolor="#47e53904"] ;
# 493 -> 494 ;
# 495 [label="IDHM <= 0.692\nsamples = 53\nvalue = [3, 23, 15, 12]", fillcolor="#47e53936"] ;
# 494 -> 495 ;
# 496 [label="samples = 16\nvalue = [0, 4, 7, 5]", fillcolor="#399de52e"] ;
# ...
# 1005 -> 1006 ;
# 1007 [label="IDHM <= 0.564\nsamples = 26\nvalue = [2, 13, 9, 2]", fillcolor="#47e5393c"] ;
# 1006 -> 1007 ;
# 1008 [label="samples = 16\nvalue = [1, 6, 7, 2]", fillcolor="#399de51a"] ;
# 1007 -> 1008 ;
# 1009 [label="samples = 10\nvalue = [1, 7, 2, 0]", fillcolor="#47e5399f"] ;
# 1007 -> 1009 ;
# 1010 [label="IDHM <= 0.665\nsamples = 261\nvalue = [22, 70, 107, 62]", fillcolor="#399de531"] ;
# 1006 -> 1010 ;
# 1011 [label="MES <= 6.5\nsamples = 45\nvalue = [4, 13, 13, 15]", fillcolor="#d739e510"] ;
# 1010 -> 1011 ;
# 1012 [label="MES <= 4.5\nsamples = 33\nvalue = [2, 7, 10, 14]", fillcolor="#d739e52c"] ;
# 1011 -> 1012 ;
# 1013 [label="MES <= 2.5\nsamples = 21\nvalue = [2, 7, 6, 6]", fillcolor="#47e53911"] ;
# 1012 -> 1013 ;
# 1014 [label="samples = 11\nvalue = [1, 3, 3, 4]", fillcolor="#d739e520"] ;
# 1013 -> 1014 ;
# 1015 [label="samples = 10\nvalue = [1, 4, 3, 2]", fillcolor="#47e53924"] ;
# 1013 -> 1015 ;
# 1016 [label="samples = 12\nvalue = [0, 0, 4, 8]", fillcolor="#d739e57f"] ;
# 1012 -> 1016 ;
# 1017 [label="samples = 12\nvalue = [2, 6, 3, 1]", fillcolor="#47e53955"] ;
# 1011 -> 1017 ;
# 1018 [label="IDHM <= 0.692\nsamples = 216\nvalue = [18, 57, 94, 47]", fillcolor="#399de53b"] ;
# 1010 -> 1018 ;
# 1019 [label="MES <= 4.5\nsamples = 40\nvalue = [4, 11, 23, 2]", fillcolor="#399de56a"] ;
# 1018 -> 1019 ;
# 1020 [label="MES <= 2.5\nsamples = 24\nvalue = [1, 4, 18, 1]", fillcolor="#399de5b2"] ;
# 1019 -> 1020 ;
# 1021 [label="samples = 11\nvalue = [0, 2, 8, 1]", fillcolor="#399de5aa"] ;
# 1020 -> 1021 ;
# 1022 [label="samples = 13\nvalue = [1, 2, 10, 0]", fillcolor="#399de5b9"] ;
# 1020 -> 1022 ;
# 1023 [label="samples = 16\nvalue = [3, 7, 5, 1]", fillcolor="#47e5392e"] ;
# 1019 -> 1023 ;
# 1024 [label="MES <= 1.5\nsamples = 176\nvalue = [14, 46, 71, 45]", fillcolor="#399de531"] ;
# 1018 -> 1024 ;
# 1025 [label="IDHM <= 0.761\nsamples = 21\nvalue = [4, 2, 11, 4]", fillcolor="#399de569"] ;
# 1024 -> 1025 ;
# 1026 [label="samples = 10\nvalue = [2, 2, 4, 2]", fillcolor="#399de540"] ;
# 1025 -> 1026 ;
# 1027 [label="samples = 11\nvalue = [2, 0, 7, 2]", fillcolor="#399de58e"] ;
# 1025 -> 1027 ;
# 1028 [label="IDHM <= 0.721\nsamples = 155\nvalue = [10, 44, 60, 41]", fillcolor="#399de525"] ;
# 1024 -> 1028 ;
# 1029 [label="MES <= 5.5\nsamples = 29\nvalue = [4, 5, 13, 7]", fillcolor="#399de546"] ;
# 1028 -> 1029 ;
# 1030 [label="samples = 15\nvalue = [2, 4, 4, 5]", fillcolor="#d739e517"] ;
# 1029 -> 1030 ;
# 1031 [label="samples = 14\nvalue = [2, 1, 9, 2]", fillcolor="#399de595"] ;
# 1029 -> 1031 ;
# 1032 [label="MES <= 6.5\nsamples = 126\nvalue = [6, 39, 47, 34]", fillcolor="#399de517"] ;
# 1028 -> 1032 ;
# 1033 [label="IDHM <= 0.757\nsamples = 83\nvalue = [3, 25, 35, 20]", fillcolor="#399de52c"] ;
# 1032 -> 1033 ;
# 1034 [label="samples = 13\nvalue = [0, 7, 6, 0]", fillcolor="#47e53924"] ;
# 1033 -> 1034 ;
# 1035 [label="IDHM <= 0.766\nsamples = 70\nvalue = [3, 18, 29, 20]", fillcolor="#399de52e"] ;
# 1033 -> 1035 ;
# 1036 [label="MES <= 4.5\nsamples = 28\nvalue = [1, 10, 8, 9]", fillcolor="#47e5390d"] ;
# 1035 -> 1036 ;
# 1037 [label="samples = 17\nvalue = [1, 8, 6, 2]", fillcolor="#47e5392e"] ;
# 1036 -> 1037 ;
# 1038 [label="samples = 11\nvalue = [0, 2, 2, 7]", fillcolor="#d739e58e"] ;
# 1036 -> 1038 ;
# 1039 [label="MES <= 2.5\nsamples = 42\nvalue = [2, 8, 21, 11]", fillcolor="#399de552"] ;
# 1035 -> 1039 ;
# 1040 [label="samples = 12\nvalue = [0, 1, 5, 6]", fillcolor="#d739e524"] ;
# 1039 -> 1040 ;
# 1041 [label="MES <= 4.5\nsamples = 30\nvalue = [2, 7, 16, 5]", fillcolor="#399de564"] ;
# 1039 -> 1041 ;
# 1042 [label="samples = 13\nvalue = [1, 4, 6, 2]", fillcolor="#399de539"] ;
# 1041 -> 1042 ;
# 1043 [label="samples = 17\nvalue = [1, 3, 10, 3]", fillcolor="#399de580"] ;
# 1041 -> 1043 ;
# 1044 [label="IDHM <= 0.771\nsamples = 43\nvalue = [3, 14, 12, 14]", fillcolor="#47e53900"] ;
# 1032 -> 1044 ;
# 1045 [label="IDHM <= 0.761\nsamples = 31\nvalue = [2, 8, 9, 12]", fillcolor="#d739e523"] ;
# 1044 -> 1045 ;
# 1046 [label="samples = 17\nvalue = [1, 4, 7, 5]", fillcolor="#399de52a"] ;
# 1045 -> 1046 ;
# 1047 [label="samples = 14\nvalue = [1, 4, 2, 7]", fillcolor="#d739e54c"] ;
# 1045 -> 1047 ;
# 1048 [label="samples = 12\nvalue = [1, 6, 3, 2]", fillcolor="#47e53955"] ;
# 1044 -> 1048 ;
# 1049 [label="IDHM <= 0.646\nsamples = 123\nvalue = [4, 26, 59, 34]", fillcolor="#399de548"] ;
# 1005 -> 1049 ;
# 1050 [label="IDHM <= 0.617\nsamples = 22\nvalue = [2, 1, 8, 11]", fillcolor="#d739e537"] ;
# 1049 -> 1050 ;
# 1051 [label="samples = 10\nvalue = [1, 0, 5, 4]", fillcolor="#399de52a"] ;
# 1050 -> 1051 ;
# 1052 [label="samples = 12\nvalue = [1, 1, 3, 7]", fillcolor="#d739e571"] ;
# 1050 -> 1052 ;
# 1053 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 101\nvalue = [2, 25, 51, 23]", fillcolor="#399de557"] ;
# 1049 -> 1053 ;
# 1054 [label="IDHM <= 0.681\nsamples = 81\nvalue = [2, 16, 44, 19]", fillcolor="#399de567"] ;
# 1053 -> 1054 ;
# 1055 [label="MES <= 10.5\nsamples = 20\nvalue = [0, 5, 14, 1]", fillcolor="#399de599"] ;
# 1054 -> 1055 ;
# 1056 [label="samples = 10\nvalue = [0, 3, 7, 0]", fillcolor="#399de592"] ;
# 1055 -> 1056 ;
# 1057 [label="samples = 10\nvalue = [0, 2, 7, 1]", fillcolor="#399de59f"] ;
# 1055 -> 1057 ;
# 1058 [label="IDHM <= 0.738\nsamples = 61\nvalue = [2, 11, 30, 18]", fillcolor="#399de547"] ;
# 1054 -> 1058 ;
# 1059 [label="samples = 14\nvalue = [1, 2, 4, 7]", fillcolor="#d739e54c"] ;
# 1058 -> 1059 ;
# 1060 [label="IDHM <= 0.771\nsamples = 47\nvalue = [1, 9, 26, 11]", fillcolor="#399de56a"] ;
# 1058 -> 1060 ;
# 1061 [label="MES <= 9.5\nsamples = 36\nvalue = [1, 5, 22, 8]", fillcolor="#399de580"] ;
# 1060 -> 1061 ;
# 1062 [label="samples = 11\nvalue = [0, 4, 5, 2]", fillcolor="#399de524"] ;
# 1061 -> 1062 ;
# 1063 [label="MES <= 10.5\nsamples = 25\nvalue = [1, 1, 17, 6]", fillcolor="#399de594"] ;
# 1061 -> 1063 ;
# 1064 [label="samples = 10\nvalue = [0, 0, 7, 3]", fillcolor="#399de592"] ;
# 1063 -> 1064 ;
# 1065 [label="samples = 15\nvalue = [1, 1, 10, 3]", fillcolor="#399de595"] ;
# 1063 -> 1065 ;
# 1066 [label="samples = 11\nvalue = [0, 4, 4, 3]", fillcolor="#47e53900"] ;
# 1060 -> 1066 ;
# 1067 [label="samples = 20\nvalue = [0, 9, 7, 4]", fillcolor="#47e53927"] ;
# 1053 -> 1067 ;
# 1068 [label="MES <= 3.5\nsamples = 119\nvalue = [3, 26, 46, 44]", fillcolor="#399de507"] ;
# 988 -> 1068 ;
# 1069 [label="NMRACACOR_PARDA <= 0.5\nsamples = 29\nvalue = [0, 12, 9, 8]", fillcolor="#47e53926"] ;
# 1068 -> 1069 ;
# 1070 [label="samples = 11\nvalue = [0, 3, 6, 2]", fillcolor="#399de560"] ;
# 1069 -> 1070 ;
# 1071 [label="samples = 18\nvalue = [0, 9, 3, 6]", fillcolor="#47e53940"] ;
# 1069 -> 1071 ;
# 1072 [label="MES <= 10.5\nsamples = 90\nvalue = [3, 14, 37, 36]", fillcolor="#399de505"] ;
# 1068 -> 1072 ;
# 1073 [label="NMSEXO_FEMININO <= 0.5\nsamples = 69\nvalue = [2, 6, 31, 30]", fillcolor="#399de507"] ;
# 1072 -> 1073 ;
# 1074 [label="samples = 15\nvalue = [2, 2, 4, 7]", fillcolor="#d739e546"] ;
# 1073 -> 1074 ;
# 1075 [label="MES <= 8.5\nsamples = 54\nvalue = [0, 4, 27, 23]", fillcolor="#399de521"] ;
# 1073 -> 1075 ;
# 1076 [label="MES <= 6.5\nsamples = 31\nvalue = [0, 1, 15, 15]", fillcolor="#399de500"] ;
# 1075 -> 1076 ;
# 1077 [label="samples = 17\nvalue = [0, 0, 10, 7]", fillcolor="#399de54d"] ;
# 1076 -> 1077 ;
# 1078 [label="samples = 14\nvalue = [0, 1, 5, 8]", fillcolor="#d739e555"] ;
# 1076 -> 1078 ;
# 1079 [label="samples = 23\nvalue = [0, 3, 12, 8]", fillcolor="#399de544"] ;
# 1075 -> 1079 ;
# 1080 [label="samples = 21\nvalue = [1, 8, 6, 6]", fillcolor="#47e53922"] ;
# 1072 -> 1080 ;
# 1081 [label="IDHM <= 0.631\nsamples = 28\nvalue = [0, 3, 9, 16]", fillcolor="#d739e55e"] ;
# 987 -> 1081 ;
# 1082 [label="samples = 13\nvalue = [0, 1, 3, 9]", fillcolor="#d739e599"] ;
# 1081 -> 1082 ;
# 1083 [label="samples = 15\nvalue = [0, 2, 6, 7]", fillcolor="#d739e51c"] ;
# 1081 -> 1083 ;
# 1084 [label="MES <= 9.5\nsamples = 718\nvalue = [20, 134, 245, 319]", fillcolor="#d739e528"] ;
# 986 -> 1084 ;
# 1085 [label="MES <= 6.5\nsamples = 544\nvalue = [10, 96, 185, 253]", fillcolor="#d739e530"] ;
# 1084 -> 1085 ;
# 1086 [label="CODCID <= 294.5\nsamples = 348\nvalue = [8, 66, 108, 166]", fillcolor="#d739e53e"] ;
# 1085 -> 1086 ;
# 1087 [label="REGIAO_SUDESTE <= 0.5\nsamples = 331\nvalue = [8, 65, 105, 153]", fillcolor="#d739e536"] ;
# 1086 -> 1087 ;
# 1088 [label="IDHM <= 0.792\nsamples = 181\nvalue = [4, 43, 55, 79]", fillcolor="#d739e531"] ;
# 1087 -> 1088 ;
# 1089 [label="IDHM <= 0.757\nsamples = 131\nvalue = [1, 28, 38, 64]", fillcolor="#d739e547"] ;
# 1088 -> 1089 ;
# 1090 [label="MES <= 4.5\nsamples = 68\nvalue = [1, 18, 20, 29]", fillcolor="#d739e530"] ;
# 1089 -> 1090 ;
# 1091 [label="IDHM <= 0.719\nsamples = 39\nvalue = [1, 9, 9, 20]", fillcolor="#d739e55d"] ;
# 1090 -> 1091 ;
# 1092 [label="IDHM <= 0.665\nsamples = 25\nvalue = [1, 4, 5, 15]", fillcolor="#d739e57f"] ;
# 1091 -> 1092 ;
# 1093 [label="samples = 14\nvalue = [1, 2, 4, 7]", fillcolor="#d739e54c"] ;
# 1092 -> 1093 ;
# 1094 [label="samples = 11\nvalue = [0, 2, 1, 8]", fillcolor="#d739e5aa"] ;
# 1092 -> 1094 ;
# 1095 [label="samples = 14\nvalue = [0, 5, 4, 5]", fillcolor="#47e53900"] ;
# 1091 -> 1095 ;
# 1096 [label="IDHM <= 0.681\nsamples = 29\nvalue = [0, 9, 11, 9]", fillcolor="#399de519"] ;
# 1090 -> 1096 ;
# 1097 [label="samples = 15\nvalue = [0, 3, 7, 5]", fillcolor="#399de533"] ;
# 1096 -> 1097 ;
# 1098 [label="samples = 14\nvalue = [0, 6, 4, 4]", fillcolor="#47e53933"] ;
# 1096 -> 1098 ;
# 1099 [label="IDHM <= 0.771\nsamples = 63\nvalue = [0, 10, 18, 35]", fillcolor="#d739e560"] ;
# 1089 -> 1099 ;
# 1100 [label="IDHM <= 0.761\nsamples = 38\nvalue = [0, 4, 10, 24]", fillcolor="#d739e57f"] ;
# 1099 -> 1100 ;
# 1101 [label="samples = 16\nvalue = [0, 0, 6, 10]", fillcolor="#d739e566"] ;
# 1100 -> 1101 ;
# 1102 [label="IDHM <= 0.766\nsamples = 22\nvalue = [0, 4, 4, 14]", fillcolor="#d739e58e"] ;
# 1100 -> 1102 ;
# 1103 [label="samples = 10\nvalue = [0, 3, 2, 5]", fillcolor="#d739e549"] ;
# 1102 -> 1103 ;
# 1104 [label="samples = 12\nvalue = [0, 1, 2, 9]", fillcolor="#d739e5b2"] ;
# 1102 -> 1104 ;
# 1105 [label="MES <= 4.5\nsamples = 25\nvalue = [0, 6, 8, 11]", fillcolor="#d739e52d"] ;
# 1099 -> 1105 ;
# 1106 [label="samples = 15\nvalue = [0, 4, 5, 6]", fillcolor="#d739e51a"] ;
# 1105 -> 1106 ;
# 1107 [label="samples = 10\nvalue = [0, 2, 3, 5]", fillcolor="#d739e549"] ;
# 1105 -> 1107 ;
# 1108 [label="NMSEXO_FEMININO <= 0.5\nsamples = 50\nvalue = [3, 15, 17, 15]", fillcolor="#399de50f"] ;
# 1088 -> 1108 ;
# 1109 [label="samples = 11\nvalue = [3, 1, 4, 3]", fillcolor="#399de520"] ;
# 1108 -> 1109 ;
# 1110 [label="MES <= 3.5\nsamples = 39\nvalue = [0, 14, 13, 12]", fillcolor="#47e5390a"] ;
# 1108 -> 1110 ;
# 1111 [label="samples = 18\nvalue = [0, 5, 7, 6]", fillcolor="#399de515"] ;
# 1110 -> 1111 ;
# 1112 [label="samples = 21\nvalue = [0, 9, 6, 6]", fillcolor="#47e53933"] ;
# 1110 -> 1112 ;
# 1113 [label="MES <= 3.5\nsamples = 150\nvalue = [4, 22, 50, 74]", fillcolor="#d739e53d"] ;
# 1087 -> 1113 ;
# 1114 [label="MES <= 1.5\nsamples = 79\nvalue = [4, 12, 29, 34]", fillcolor="#d739e51a"] ;
# 1113 -> 1114 ;
# 1115 [label="samples = 31\nvalue = [1, 2, 11, 17]", fillcolor="#d739e54c"] ;
# 1114 -> 1115 ;
# 1116 [label="MES <= 2.5\nsamples = 48\nvalue = [3, 10, 18, 17]", fillcolor="#399de508"] ;
# 1114 -> 1116 ;
# 1117 [label="samples = 25\nvalue = [3, 6, 10, 6]", fillcolor="#399de536"] ;
# 1116 -> 1117 ;
# 1118 [label="samples = 23\nvalue = [0, 4, 8, 11]", fillcolor="#d739e533"] ;
# 1116 -> 1118 ;
# 1119 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 71\nvalue = [0, 10, 21, 40]", fillcolor="#d739e561"] ;
# 1113 -> 1119 ;
# 1120 [label="MES <= 5.5\nsamples = 59\nvalue = [0, 9, 15, 35]", fillcolor="#d739e574"] ;
# 1119 -> 1120 ;
# 1121 [label="MES <= 4.5\nsamples = 39\nvalue = [0, 3, 11, 25]", fillcolor="#d739e580"] ;
# 1120 -> 1121 ;
# 1122 [label="samples = 21\nvalue = [0, 2, 5, 14]", fillcolor="#d739e58f"] ;
# 1121 -> 1122 ;
# 1123 [label="samples = 18\nvalue = [0, 1, 6, 11]", fillcolor="#d739e56a"] ;
# 1121 -> 1123 ;
# 1124 [label="samples = 20\nvalue = [0, 6, 4, 10]", fillcolor="#d739e549"] ;
# 1120 -> 1124 ;
# 1125 [label="samples = 12\nvalue = [0, 1, 6, 5]", fillcolor="#399de524"] ;
# 1119 -> 1125 ;
# 1126 [label="samples = 17\nvalue = [0, 1, 3, 13]", fillcolor="#d739e5b6"] ;
# 1086 -> 1126 ;
# 1127 [label="IDHM <= 0.814\nsamples = 196\nvalue = [2, 30, 77, 87]", fillcolor="#d739e515"] ;
# 1085 -> 1127 ;
# 1128 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 174\nvalue = [2, 28, 71, 73]", fillcolor="#d739e505"] ;
# 1127 -> 1128 ;
# 1129 [label="MES <= 7.5\nsamples = 143\nvalue = [1, 20, 59, 63]", fillcolor="#d739e50c"] ;
# 1128 -> 1129 ;
# 1130 [label="IDHM <= 0.737\nsamples = 51\nvalue = [0, 6, 24, 21]", fillcolor="#399de51a"] ;
# 1129 -> 1130 ;
# 1131 [label="samples = 16\nvalue = [0, 3, 10, 3]", fillcolor="#399de589"] ;
# 1130 -> 1131 ;
# 1132 [label="REGIAO_SUDESTE <= 0.5\nsamples = 35\nvalue = [0, 3, 14, 18]", fillcolor="#d739e531"] ;
# 1130 -> 1132 ;
# 1133 [label="samples = 16\nvalue = [0, 1, 8, 7]", fillcolor="#399de51c"] ;
# 1132 -> 1133 ;
# 1134 [label="samples = 19\nvalue = [0, 2, 6, 11]", fillcolor="#d739e562"] ;
# 1132 -> 1134 ;
# 1135 [label="IDHM <= 0.766\nsamples = 92\nvalue = [1, 14, 35, 42]", fillcolor="#d739e51f"] ;
# 1129 -> 1135 ;
# 1136 [label="MES <= 8.5\nsamples = 29\nvalue = [1, 3, 8, 17]", fillcolor="#d739e56d"] ;
# 1135 -> 1136 ;
# 1137 [label="samples = 16\nvalue = [0, 3, 5, 8]", fillcolor="#d739e546"] ;
# 1136 -> 1137 ;
# 1138 [label="samples = 13\nvalue = [1, 0, 3, 9]", fillcolor="#d739e599"] ;
# 1136 -> 1138 ;
# 1139 [label="IDHM <= 0.792\nsamples = 63\nvalue = [0, 11, 27, 25]", fillcolor="#399de50d"] ;
# 1135 -> 1139 ;
# 1140 [label="samples = 13\nvalue = [0, 3, 6, 4]", fillcolor="#399de539"] ;
# 1139 -> 1140 ;
# 1141 [label="MES <= 8.5\nsamples = 50\nvalue = [0, 8, 21, 21]", fillcolor="#399de500"] ;
# 1139 -> 1141 ;
# 1142 [label="samples = 23\nvalue = [0, 2, 10, 11]", fillcolor="#d739e514"] ;
# 1141 -> 1142 ;
# 1143 [label="samples = 27\nvalue = [0, 6, 11, 10]", fillcolor="#399de50f"] ;
# 1141 -> 1143 ;
# 1144 [label="IDHM <= 0.789\nsamples = 31\nvalue = [1, 8, 12, 10]", fillcolor="#399de518"] ;
# 1128 -> 1144 ;
# 1145 [label="samples = 18\nvalue = [1, 3, 7, 7]", fillcolor="#399de500"] ;
# 1144 -> 1145 ;
# 1146 [label="samples = 13\nvalue = [0, 5, 5, 3]", fillcolor="#47e53900"] ;
# 1144 -> 1146 ;
# 1147 [label="samples = 22\nvalue = [0, 2, 6, 14]", fillcolor="#d739e580"] ;
# 1127 -> 1147 ;
# 1148 [label="IDHM <= 0.681\nsamples = 174\nvalue = [10, 38, 60, 66]", fillcolor="#d739e50d"] ;
# 1084 -> 1148 ;
# 1149 [label="samples = 19\nvalue = [0, 4, 3, 12]", fillcolor="#d739e588"] ;
# 1148 -> 1149 ;
# 1150 [label="IDHM <= 0.787\nsamples = 155\nvalue = [10, 34, 57, 54]", fillcolor="#399de508"] ;
# 1148 -> 1150 ;
# 1151 [label="IDHM <= 0.771\nsamples = 70\nvalue = [4, 16, 31, 19]", fillcolor="#399de53c"] ;
# 1150 -> 1151 ;
# 1152 [label="IDHM <= 0.718\nsamples = 51\nvalue = [3, 10, 21, 17]", fillcolor="#399de51e"] ;
# 1151 -> 1152 ;
# 1153 [label="MES <= 10.5\nsamples = 23\nvalue = [0, 7, 11, 5]", fillcolor="#399de540"] ;
# 1152 -> 1153 ;
# 1154 [label="samples = 11\nvalue = [0, 3, 5, 3]", fillcolor="#399de540"] ;
# 1153 -> 1154 ;
# 1155 [label="samples = 12\nvalue = [0, 4, 6, 2]", fillcolor="#399de540"] ;
# 1153 -> 1155 ;
# 1156 [label="IDHM <= 0.723\nsamples = 28\nvalue = [3, 3, 10, 12]", fillcolor="#d739e51c"] ;
# 1152 -> 1156 ;
# 1157 [label="samples = 10\nvalue = [2, 1, 4, 3]", fillcolor="#399de524"] ;
# 1156 -> 1157 ;
# 1158 [label="samples = 18\nvalue = [1, 2, 6, 9]", fillcolor="#d739e540"] ;
# 1156 -> 1158 ;
# 1159 [label="samples = 19\nvalue = [1, 6, 10, 2]", fillcolor="#399de54e"] ;
# 1151 -> 1159 ;
# 1160 [label="NMSEXO_MASCULINO <= 0.5\nsamples = 85\nvalue = [6, 18, 26, 35]", fillcolor="#d739e527"] ;
# 1150 -> 1160 ;
# 1161 [label="REGIAO_SUDESTE <= 0.5\nsamples = 68\nvalue = [5, 16, 16, 31]", fillcolor="#d739e54a"] ;
# 1160 -> 1161 ;
# 1162 [label="samples = 15\nvalue = [2, 4, 1, 8]", fillcolor="#d739e55d"] ;
# 1161 -> 1162 ;
# 1163 [label="MES <= 10.5\nsamples = 53\nvalue = [3, 12, 15, 23]", fillcolor="#d739e536"] ;
# 1161 -> 1163 ;
# 1164 [label="samples = 17\nvalue = [2, 3, 4, 8]", fillcolor="#d739e54e"] ;
# 1163 -> 1164 ;
# 1165 [label="MES <= 11.5\nsamples = 36\nvalue = [1, 9, 11, 15]", fillcolor="#d739e529"] ;
# 1163 -> 1165 ;
# 1166 [label="samples = 14\nvalue = [1, 4, 4, 5]", fillcolor="#d739e51a"] ;
# 1165 -> 1166 ;
# 1167 [label="samples = 22\nvalue = [0, 5, 7, 10]", fillcolor="#d739e533"] ;
# 1165 -> 1167 ;
# 1168 [label="samples = 17\nvalue = [1, 2, 10, 4]", fillcolor="#399de576"] ;
# 1160 -> 1168 ;
# }

# %%
confusion_matrix = cm(y_test, y_pred, )
confusion_matrix
# Out:
# array([[279, 111,  80,  20],
#        [148, 162, 127,  80],
#        [126, 152, 136, 116],
#        [ 79,  78, 133, 173]], dtype=int64)

# %%
print(classification_report(y_test, y_pred));
# Out:
#                 precision    recall  f1-score   support
#
#       Infantil       0.44      0.57      0.50       490
# Leite com Pêra       0.32      0.31      0.32       517
#     Meia-idade       0.29      0.26      0.27       530
#     Pé na Cova       0.44      0.37      0.41       463
#
#      micro avg       0.38      0.38      0.38      2000
#      macro avg       0.37      0.38      0.37      2000
#   weighted avg       0.37      0.38      0.37      2000

# %% [markdown]
# ******Regressão Logística********

# %%
X_train.columns
# Out:
# Index(['IDHM', 'CODCID', 'MES', 'NMSEXO_FEMININO', 'NMSEXO_MASCULINO',
#        'NMRACACOR_BRANCA', 'NMRACACOR_PARDA', 'NMESTCIV_CASADO',
#        'NMESTCIV_SEPARADO', 'NMESTCIV_SOLTEIRO', 'NMESTCIV_VIUVO',
#        'REGIAO_NORDESTE', 'REGIAO_SUDESTE'],
#       dtype='object')

# %%
logres.coef_
# Out:
# array([[ 1.63188535e-01, -1.14315951e-03,  8.08229387e-03,
#          4.74534489e-02,  2.09394163e-01, -1.82651717e-01,
#          8.51287189e-02, -3.07046187e-01,  9.39235795e-02,
#          3.66983306e-01, -1.27002199e+00, -2.81727985e-01,
#         -6.31016938e-02],
#        [-5.04236883e-03,  2.01191366e-03, -8.86701907e-03,
#          1.02665585e-02, -9.81692536e-02, -9.85577476e-02,
#          4.59581316e-02,  3.80230841e-01,  1.30873576e-01,
#          4.70824446e-02, -1.40720946e-01,  1.40180381e-03,
#          2.97015852e-02],
#        [-6.68441013e-02,  3.60114747e-04,  1.08811911e-02,
#         -1.45570413e-02, -7.04923826e-02,  1.18548422e-01,
#          3.88983581e-02,  2.02558880e-01,  4.90431642e-03,
#         -2.25822014e-01,  4.62635093e-01,  1.18449497e-01,
#         -2.90364840e-03],
#        [-9.13020648e-02, -1.22886890e-03, -1.00964659e-02,
#         -4.31629660e-02, -4.07325269e-02,  1.62661042e-01,
#         -1.69985209e-01, -2.75743534e-01, -2.29701472e-01,
#         -1.88243737e-01,  9.48107841e-01,  1.61876684e-01,
#          3.63037570e-02]])

# %%
logres = LogisticRegression(solver='lbfgs',multi_class='auto')
logres.fit(X_train, y_train)
# Out:
# C:\Users\lenon\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:758: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
pred_logres = logres.predict(X_test)
print(pred_logres)
# Out:
# ['Pé na Cova' 'Leite com Pêra' 'Infantil' ... 'Pé na Cova'
#  'Leite com Pêra' 'Infantil']

# %%
pred_logres == y_pred
# Out:
# array([False,  True, False, ..., False,  True, False])

# %%
print(classification_report(y_test, pred_logres))
print('******************************************************')
print(classification_report(y_test, y_pred))
# Out:
#                 precision    recall  f1-score   support
#
#       Infantil       0.42      0.62      0.50       490
# Leite com Pêra       0.35      0.42      0.38       517
#     Meia-idade       0.37      0.13      0.19       530
#     Pé na Cova       0.48      0.49      0.49       463
#
#      micro avg       0.41      0.41      0.41      2000
#      macro avg       0.41      0.41      0.39      2000
#   weighted avg       0.40      0.41      0.38      2000
#
# ******************************************************
#                 precision    recall  f1-score   support
#
#       Infantil       0.44      0.57      0.50       490
# Leite com Pêra       0.32      0.31      0.32       517
#     Meia-idade       0.29      0.26      0.27       530
#     Pé na Cova       0.44      0.37      0.41       463
#
#      micro avg       0.38      0.38      0.38      2000
#      macro avg       0.37      0.38      0.37      2000
#   weighted avg       0.37      0.38      0.37      2000

# %%
import xgboost

# %%
model = xgboost.XGBClassifier(n_estimators=500, n_jobs=-1).fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import roc_auc_score

# %%
print(classification_report(y_test, model.predict(X_test)))
# Out:
#                 precision    recall  f1-score   support
#
#       Infantil       0.49      0.57      0.52       490
# Leite com Pêra       0.36      0.40      0.38       517
#     Meia-idade       0.36      0.32      0.34       530
#     Pé na Cova       0.52      0.44      0.48       463
#
#      micro avg       0.43      0.43      0.43      2000
#      macro avg       0.43      0.43      0.43      2000
#   weighted avg       0.43      0.43      0.43      2000

# %%
roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-2447ec555208> in <module>
# ----> 1 roc_auc_score(y_test, model.predict_proba(X_test))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     354     return _average_binary_score(
#     355         _binary_roc_auc_score, y_true, y_score, average,
# --> 356         sample_weight=sample_weight)
#     357
#     358
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      72     y_type = type_of_target(y_true)
#      73     if y_type not in ("binary", "multilabel-indicator"):
# ---> 74         raise ValueError("{0} format is not supported".format(y_type))
#      75
#      76     if y_type == "binary":
#
# ValueError: multiclass format is not supported
